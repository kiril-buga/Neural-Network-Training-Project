# %% [markdown]
# <a href="https://colab.research.google.com/github/kiril-buga/Neural-Network-Training-Project/blob/main/1D_CNN_Multilabel_V1/DataExploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Load the dataset from the shared Google Drive

# %%
# ===== Imports =====
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Set this to True to download from Huggingface else use Google Drive
USE_HF = True

# %%
if USE_HF:
    from huggingface_hub import snapshot_download
    local_dir = snapshot_download(
        repo_id="Neural-Network-Project/ECG-database",
        repo_type="dataset",
        allow_patterns="data/*.csv",  # This filter restricts download to the 'data' folder
        local_dir="./data",
        local_dir_use_symlinks=False
    )
    print("Downloaded to:", local_dir)
else:
    from google.colab import drive
    drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloaded to: /content/data

# %%
if USE_HF and local_dir:
  # Case 2: You want to download the dataset from Huggingface
    DATA_PATH = f"{local_dir}/data/"
    ARTIFACT_DIR = f"{local_dir}/artifacts/"

else:
  # ===== Detect if running in Google Colab and mount Drive =====
  IN_COLAB = False
  try:
      from google.colab import drive  # type: ignore
      IN_COLAB = True
  except Exception:
      drive = None
      IN_COLAB = False

  if IN_COLAB:
      drive.mount('/content/drive/')

  # ===== Define paths =====
  if IN_COLAB:
      # Case 1: You manually placed the dataset in MyDrive
      DATA_PATH = "/content/drive/MyDrive/DeepLearningECG/data/"
      ARTIFACT_DIR = "/content/drive/MyDrive/DeepLearningECG/artifacts/"

  else:
      # Case 3: Local fallback (if running outside Colab)
      DATA_PATH = "../data/"
      ARTIFACT_DIR = "../artifacts/"

print("DATA_PATH:", DATA_PATH)
print("ARTIFACT_DIR:", ARTIFACT_DIR)
print("Files in DATA_PATH:", os.listdir(DATA_PATH))
# Out:
# DATA_PATH: /content/data/data/
# ARTIFACT_DIR: /content/data/artifacts/
# Files in DATA_PATH: ['ECGCode.csv', 'DiseaseCode.csv', 'AttributesDictionary.csv']

# %% [markdown]
# 3. Load the CSV metadata

# %%
# ===== Load CSV metadata =====
ATTR_PATH = os.path.join(DATA_PATH, "AttributesDictionary.csv")
DISEASE_PATH = os.path.join(DATA_PATH, "DiseaseCode.csv")
ECGCODE_PATH = os.path.join(DATA_PATH, "ECGCode.csv")

df_attr = pd.read_csv(ATTR_PATH)
df_disease = pd.read_csv(DISEASE_PATH)
df_ecgcode = pd.read_csv(ECGCODE_PATH)

print("Attributes shape:", df_attr.shape)
display(df_attr.head())

print("DiseaseCode shape:", df_disease.shape)
display(df_disease.head())

print("ECGCode shape:", df_ecgcode.shape)
display(df_ecgcode.head())
# Out:
# Attributes shape: (14190, 14)
#                 Filename      ECG_ID Patient_ID    Age    Gender  \
# 0  P00/P00001/P00001_E01  P00001_E01     P00001   572d  'Female'
# 1  P00/P00002/P00002_E01  P00002_E01     P00002  4327d    'Male'
# 2  P00/P00003/P00003_E01  P00003_E01     P00003  1087d  'Female'
# 3  P00/P00004/P00004_E01  P00004_E01     P00004  2465d    'Male'
# 4  P00/P00004/P00004_E02  P00004_E02     P00004  2461d    'Male'
#
#       Acquisition_date  Sampling_point  Lead  \
# 0  2017-11-22 10:46:08            9000     9
# 1  2017-11-28 21:59:47           15000    12
# 2  2017-11-29 16:04:57           10000    12
# 3  2017-11-30 15:21:27           13000     9
# 4  2017-11-26 19:19:48           15000     9
#
#                                  AHA_code       CHN_code  \
# 0  'Left ventricular high voltage';'L147'  'J106';'L123'
# 1                                   'C21'          'C13'
# 2                                   'C21'          'C13'
# ...

# %% [markdown]
# 4. Simple data analysis (EDA)

# %%
# ===== Basic statistics and structure =====

print("Shape:", df_attr.shape)
print("\nColumn types:")
print(df_attr.dtypes)

print("\nMissing values per column:")
print(df_attr.isna().sum())

print("\n----- Numerical Summary -----")
display(df_attr.describe(include="all"))
# Out:
# Shape: (14190, 14)
#
# Column types:
# Filename            object
# ECG_ID              object
# Patient_ID          object
# Age                 object
# Gender              object
# Acquisition_date    object
# Sampling_point       int64
# Lead                 int64
# AHA_code            object
# CHN_code            object
# ICD-10 code         object
# pSQI                object
# basSQI              object
# bSQI                object
# dtype: object
#
# Missing values per column:
# Filename            0
# ECG_ID              0
# Patient_ID          0
# Age                 0
# Gender              0
# Acquisition_date    0
# Sampling_point      0
# Lead                0
# AHA_code            0
# CHN_code            0
# ICD-10 code         0
# pSQI                0
# basSQI              0
# bSQI                0
# dtype: int64
#
# ----- Numerical Summary -----
#                      Filename      ECG_ID Patient_ID    Age  Gender  \
# ...

# %%
# ===== Age distribution =====

# Age is stored as "###d" (days). Convert to integer days.
df_attr["Age_days"] = df_attr["Age"].str.replace("d", "").astype(int)
df_attr["Age_years"] = df_attr["Age_days"] / 365

plt.figure(figsize=(8,5))
plt.hist(df_attr["Age_years"], bins=60)
plt.xlabel("Age (years)")
plt.ylabel("Count")
plt.title("Distribution of patient age")
plt.show()

print("Min age (days):", df_attr["Age_days"].min())
print("Max age (days):", df_attr["Age_days"].max())
print("Average age (days):", df_attr["Age_days"].mean())

# How many have age = 0 days?
num_age_zero = (df_attr["Age_days"] == 0).sum()
print("Number of ECG records with age = 0 days:", num_age_zero)
# Out:
# Min age (days): 1
# Max age (days): 5474
# Average age (days): 2983.5233967582803
# Number of ECG records with age = 0 days: 0

# %%
# ===== Gender distribution =====

plt.figure(figsize=(5,4))
df_attr["Gender"].value_counts().plot(kind="bar")
plt.title("Gender distribution")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

print(df_attr["Gender"].value_counts())
# Out:
# Gender
# 'Male'      8131
# 'Female'    6059
# Name: count, dtype: int64

# %%
# ===== Number of electrodes per ECG (9 vs 12) =====

plt.figure(figsize=(5,4))
df_attr["Lead"].value_counts().plot(kind="bar")
plt.title("Number of leads per ECG")
plt.xlabel("Lead count")
plt.ylabel("Number of ECG records")
plt.show()

print(df_attr["Lead"].value_counts())
# Out:
# Lead
# 12    12334
# 9      1856
# Name: count, dtype: int64

# %%
# Ensure Age_days exists
df_attr["Age_days"] = df_attr["Age"].str.replace("d", "").astype(int)
df_attr["Age_years"] = df_attr["Age_days"] / 365

# Split by lead type
df_9 = df_attr[df_attr["Lead"] == 9]
df_12 = df_attr[df_attr["Lead"] == 12]

print("Average age (9-lead):", df_9["Age_years"].mean())
print("Average age (12-lead):", df_12["Age_years"].mean())
print("Median age (9-lead):", df_9["Age_years"].median())
print("Median age (12-lead):", df_12["Age_years"].median())
print("Min age 9-lead:", df_9["Age_years"].min())
print("Min age 12-lead:", df_12["Age_years"].min())
print("Max age 9-lead:", df_9["Age_years"].max())
print("Max age 12-lead:", df_12["Age_years"].max())

# Plot both age distributions
plt.figure(figsize=(10,5))
plt.hist(df_9["Age_years"], bins=40, alpha=0.6, label="9-lead")
plt.hist(df_12["Age_years"], bins=40, alpha=0.6, label="12-lead")
plt.xlabel("Age (years)")
plt.ylabel("Count")
plt.title("Age distribution: 9-lead vs 12-lead ECGs")
plt.legend()
plt.show()
# Out:
# Average age (9-lead): 1.6965753424657537
# Average age (12-lead): 9.148754417569432
# Median age (9-lead): 1.0136986301369864
# Median age (12-lead): 9.686301369863013
# Min age 9-lead: 0.0027397260273972603
# Min age 12-lead: 0.005479452054794521
# Max age 9-lead: 6.983561643835617
# Max age 12-lead: 14.997260273972604

# %%
# ===== ECG duration distribution =====
#Assuming sampling frequency = 500 Hz

df_attr["Duration_sec"] = df_attr["Sampling_point"] / 500

plt.figure(figsize=(8,5))
plt.hist(df_attr["Duration_sec"], bins=40)
plt.xlabel("Duration (seconds)")
plt.ylabel("Count")
plt.title("Distribution of ECG signal length")
plt.show()

print("Min duration:", df_attr["Duration_sec"].min(), "sec")
print("Max duration:", df_attr["Duration_sec"].max(), "sec")
print("Average duration:", df_attr["Duration_sec"].mean(), "sec")

# Distribution in a table
# Create bins of 5 seconds
bins = list(range(0, int(df_attr["Duration_sec"].max()) + 5, 5))

df_attr["Duration_bin"] = pd.cut(
    df_attr["Duration_sec"],
    bins=bins,
    right=False,   # intervals like [0–5), [5–10), ...
    labels=[f"{b}-{b+5}s" for b in bins[:-1]]
)

duration_table = df_attr["Duration_bin"].value_counts().sort_index()
duration_table
# Out:
# Min duration: 5.0 sec
# Max duration: 120.0 sec
# Average duration: 27.008315715292458 sec
# Duration_bin
# 0-5s           0
# 5-10s          7
# 10-15s       147
# 15-20s       780
# 20-25s      3118
# 25-30s       618
# 30-35s      9422
# 35-40s        26
# 40-45s        10
# 45-50s        13
# 50-55s         4
# 55-60s         4
# 60-65s        26
# 65-70s         4
# 70-75s         2
# 75-80s         2
# 80-85s         0
# 85-90s         1
# 90-95s         2
# 95-100s        0
# 100-105s       1
# 105-110s       1
# 110-115s       1
# 115-120s       0
# Name: count, dtype: int64

# %%
# === Define cleaned cardiovascular ICD codes ===
cardio_icds = [
    "I40.0", "I40.9", "I51.4",
    "I42.0", "I42.2", "I42.9", "Q24.8",
    "M30.3",
    "Q21.0", "Q21.1", "Q21.2", "Q21.3",
    "Q22.1", "Q25.0", "Q25.6", "I37.0"
]

# === Load dataset ===
df_attr = pd.read_csv(ATTR_PATH)

# === Cleaning function ===
def clean_icd_str(icd):
    icd = str(icd).strip().replace("'", "")
    if ")" in icd:
        icd = icd.split(")")[-1].strip()
    return icd

# === Extract and clean ALL ICD codes per ECG ===
df_attr["ICD_list_clean"] = (
    df_attr["ICD-10 code"]
    .fillna("")
    .astype(str)
    .apply(lambda s: [
        clean_icd_str(x)
        for x in s.split(";")
        if x.strip() not in ["", "nan", "None"]
    ])
)

# === Determine whether ECG has ANY CV disease ICD code ===
df_attr["has_cv_disease"] = df_attr["ICD_list_clean"].apply(
    lambda codes: any(code in cardio_icds for code in codes)
)


# === Count ECGs with vs. without CV diagnosis ===
cv_counts = df_attr["has_cv_disease"].value_counts()

# Rename for clarity
cv_counts.index = ["Healthy / No CV ICD", "CV ICD present"] if False in cv_counts.index else ["CV ICD present", "Healthy / No CV ICD"]

# === Visualization ===
plt.figure(figsize=(6,5))
cv_counts.plot(kind="bar")
plt.title("ECG Count: Cardiovascular ICD Present vs. Healthy")
plt.ylabel("Number of ECG recordings")
plt.xticks(rotation=0)
plt.show()

# === Table output ===
cv_counts_df = cv_counts.reset_index()
cv_counts_df.columns = ["Category", "Number of ECGs"]
cv_counts_df
# Out:
#               Category  Number of ECGs
# 0  Healthy / No CV ICD           10474
# 1       CV ICD present            3716

# %%
# === Define cleaned cardiovascular ICD codes ===
cardio_icds = [
    "I40.0", "I40.9", "I51.4",
    "I42.0", "I42.2", "I42.9", "Q24.8",
    "M30.3",
    "Q21.0", "Q21.1", "Q21.2", "Q21.3",
    "Q22.1", "Q25.0", "Q25.6", "I37.0"
]

# === Function to clean ICD codes as in preprocessing ===
def clean_icd_str(icd):
    icd = icd.strip().replace("'", "")
    if ")" in icd:
        icd = icd.split(")")[-1].strip()
    return icd

# === Extract and clean all ICD codes ===
codes = (
    df_attr["ICD-10 code"]
    .dropna()
    .astype(str)
    .str.split(";")
)

clean_flat = []

for lst in codes:
    for x in lst:
        cleaned = clean_icd_str(x)
        clean_flat.append(cleaned)

# === Keep only cardiovascular ICDs ===
cardio_only = [c for c in clean_flat if c in cardio_icds]

# === Count ===
icd_counts_cardio = pd.Series(cardio_only).value_counts().sort_values(ascending=False)

# === Plot ===
plt.figure(figsize=(10,6))
icd_counts_cardio.plot(kind="bar")
plt.title("Distribution of Pediatric Cardiovascular ICD-10 Codes")
plt.xlabel("ICD-10 code")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

icd_counts_cardio

# === Convert to table and add total row ===
icd_table = icd_counts_cardio.reset_index()
icd_table.columns = ["ICD-10 Code", "Count"]

# Add total row
total_row = pd.DataFrame({"ICD-10 Code": ["Total"], "Count": [icd_counts_cardio.sum()]})
icd_table = pd.concat([icd_table, total_row], ignore_index=True)

# === Display table ===
icd_table
# Out:
#    ICD-10 Code  Count
# 0        Q21.1   1624
# 1        Q21.0   1062
# 2        I40.0    379
# 3        Q25.0    348
# 4        M30.3    194
# 5        I51.4    186
# 6        Q21.3     89
# 7        I42.0     86
# 8        I37.0     81
# 9        I40.9     70
# 10       Q21.2     61
# 11       Q22.1     24
# 12       I42.2     24
# 13       Q24.8     22
# 14       Q25.6     18
# 15       I42.9     18
# 16       Total   4286

# %%
# === Load disease mapping from CSV ===
df_map = pd.read_csv(DISEASE_PATH, encoding='latin1')

# === Function to clean ICD codes as in preprocessing ===
def clean_icd_str(icd):
    icd = str(icd).strip().replace("'", "")
    if ")" in icd:
        icd = icd.split(")")[-1].strip()
    return icd

# Clean ICD codes in mapping file
df_map["ICD_clean"] = df_map["ICD-10 Code"].apply(clean_icd_str)

# === Build 1→1 mapping by dropping duplicates ===
df_map_unique = df_map.drop_duplicates(subset=["ICD_clean"])
icd_to_type = dict(zip(df_map_unique["ICD_clean"], df_map_unique["Disease Type"]))

# === Load attributes dataset ===
df_attr = pd.read_csv(ATTR_PATH)

# Extract ICD codes from dataset
codes = (
    df_attr["ICD-10 code"]
    .dropna()
    .astype(str)
    .str.split(";")
)

# Clean and flatten ICD list
clean_flat = []
for lst in codes:
    for x in lst:
        cleaned = clean_icd_str(x)
        clean_flat.append(cleaned)

# === Count disease types (each ICD contributes exactly once) ===
type_counts = {}

for icd in clean_flat:
    if icd in icd_to_type:
        t = icd_to_type[icd]   # exactly one type per ICD
        type_counts[t] = type_counts.get(t, 0) + 1

type_counts = pd.Series(type_counts).sort_values(ascending=False)

# === Plot ===
plt.figure(figsize=(10,6))
type_counts.plot(kind="bar")
plt.title("Counts of ICD Codes Grouped by Pediatric Cardiovascular Disease Types")
plt.xlabel("Disease Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

type_counts

# === Convert to table and add total row ===
type_counts_table = type_counts.reset_index()
type_counts_table.columns = ["Disease Type", "Count"]

total_row = pd.DataFrame({"Disease Type": ["Total"], "Count": [type_counts.sum()]})
type_counts_table = pd.concat([type_counts_table, total_row], ignore_index=True)

type_counts_table
# Out:
#                  Disease Type  Count
# 0  Congenital \nheart disease   3307
# 1                 Myocarditis    635
# 2            Kawasaki disease    194
# 3              Cardiomyopathy    150
# 4                       Total   4286

# %%
# === Load disease mapping from CSV ===
df_map = pd.read_csv(DISEASE_PATH, encoding='latin1')

# === Function to clean ICD codes as in preprocessing ===
def clean_icd_str(icd):
    icd = str(icd).strip().replace("'", "")
    if ")" in icd:
        icd = icd.split(")")[-1].strip()
    return icd

# Clean ICD codes in mapping file
df_map["ICD_clean"] = df_map["ICD-10 Code"].apply(clean_icd_str)

# === Build 1→1 mapping: ICD -> Disease Type (drop duplicates) ===
df_map_unique = df_map.drop_duplicates(subset=["ICD_clean"])
icd_to_type = dict(zip(df_map_unique["ICD_clean"], df_map_unique["Disease Type"]))

# === Load attributes dataset ===
df_attr = pd.read_csv(ATTR_PATH)

# === Extract ONLY the primary ICD code (first code in the line) ===
df_attr["ICD_primary"] = (
    df_attr["ICD-10 code"]
    .astype(str)
    .apply(lambda s: s.split(";")[0] if s not in ["nan", "None"] else None)
)

# Clean the primary ICD codes
df_attr["ICD_primary_clean"] = df_attr["ICD_primary"].apply(
    lambda x: clean_icd_str(x) if pd.notna(x) else None
)

# === Count disease types using ONLY primary ICD code (1→1 mapping) ===
type_counts_primary = {}

for icd in df_attr["ICD_primary_clean"]:
    if icd in icd_to_type:
        t = icd_to_type[icd]   # exactly one disease type per ICD
        type_counts_primary[t] = type_counts_primary.get(t, 0) + 1

type_counts_primary = pd.Series(type_counts_primary).sort_values(ascending=False)

# === Plot ===
plt.figure(figsize=(10,6))
type_counts_primary.plot(kind="bar")
plt.title("Counts of PRIMARY ICD Codes Grouped by Pediatric Cardiovascular Disease Types")
plt.xlabel("Disease Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

type_counts_primary

# === Convert to table and add total row ===
type_counts_primary_table = type_counts_primary.reset_index()
type_counts_primary_table.columns = ["Disease Type", "Count"]

total_row = pd.DataFrame({"Disease Type": ["Total"], "Count": [type_counts_primary.sum()]})
type_counts_primary_table = pd.concat([type_counts_primary_table, total_row], ignore_index=True)

type_counts_primary_table
# Out:
#                  Disease Type  Count
# 0  Congenital \nheart disease   1601
# 1                 Myocarditis    520
# 2            Kawasaki disease     67
# 3              Cardiomyopathy     58
# 4                       Total   2246

# %%
# ===== Number of ECGs per patient =====

patient_counts = df_attr["Patient_ID"].value_counts()

plt.figure(figsize=(6,4))
plt.hist(patient_counts, bins=20)
plt.xlabel("ECG records per patient")
plt.ylabel("Count")
plt.title("Distribution of ECG count per patient")
plt.show()

print(patient_counts.describe())

# Table: ECG count → number of patients
ecg_count_table = patient_counts.value_counts().sort_index()

# Convert to DataFrame
ecg_count_df = pd.DataFrame({
    "ECG recordings per patient": ecg_count_table.index,
    "Number of patients": ecg_count_table.values
})

display(ecg_count_df)
# Out:
# count    11643.000000
# mean         1.218758
# std          0.777619
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         19.000000
# Name: count, dtype: float64
#     ECG recordings per patient  Number of patients
# 0                            1                9952
# 1                            2                1327
# 2                            3                 202
# 3                            4                  66
# 4                            5                  33
# 5                            6                  18
# 6                            7                   9
# 7                            8                   7
# 8                            9                  11
# 9                           10                   9
# 10                          11                   3
# 11                          14                   1
# 12                          15                   1
# ...
