# %% [markdown]
# <a href="https://colab.research.google.com/github/kiril-buga/Neural-Network-Training-Project/blob/main/ECG_Model_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ECG Baseline Model Training
#
# This notebook trains a baseline deep learning model on preprocessed ECG data:
# 1. Loads preprocessed windows and labels from ECG_Preprocessing.ipynb
# 2. Performs patient-level train/validation/test splitting
# 3. Builds and trains a 1D CNN baseline model
# 4. Evaluates performance and saves results

# %% [markdown]
# ### Step 1: Install Dependencies and Import Libraries
# Install TensorFlow/Keras for deep learning and import necessary packages:
# - **tensorflow/keras**: Deep learning framework
# - **scikit-learn**: Model evaluation metrics and utilities
# - **numpy/pandas**: Numerical computing and data manipulation
# - **matplotlib**: Visualization of training metrics

# %%
# !pip install tensorflow scikit-learn matplotlib seaborn

import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, confusion_matrix, accuracy_score,
    precision_recall_fscore_support, roc_auc_score
)

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# TensorFlow version: 2.19.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Step 2: Configure Paths and Load Preprocessing Artifacts
# Set up directories and load the data, labels, and metadata generated by ECG_Preprocessing.ipynb:
# - **X**: Preprocessed ECG windows (N, T, C)
# - **y**: Integer labels for each window
# - **df_qc**: QC metrics and pass/fail information
# - **label_mapping**: Mapping between diagnosis codes and integer indices

# %%
# Set this to True to download from Huggingface else use Google Drive
USE_HF = True

if USE_HF:
  from huggingface_hub import snapshot_download
  local_dir = snapshot_download(
      repo_id="kiril-buga/ECG-database",
      repo_type="dataset",
      local_dir="/content/ECG-database/" # Specify the desired download directory
  )
  print("Downloaded to:", local_dir)

  DATA_PATH = f"{local_dir}/data/"
  ARTIFACT_DIR = f"{local_dir}/artifacts/"

else:
    from google.colab import drive
    drive.mount('/content/drive')

    # ===== Detect if running in Google Colab and mount Drive =====
    IN_COLAB = False
    try:
        from google.colab import drive  # type: ignore
        IN_COLAB = True
    except Exception:
        drive = None
        IN_COLAB = False

    if IN_COLAB:
        drive.mount('/content/drive/')

    # ===== Define paths =====
    if IN_COLAB:
        # Case 1: You manually placed the dataset in MyDrive
        DATA_PATH = "/content/drive/MyDrive/DeepLearningECG/data/"
        ARTIFACT_DIR = "/content/drive/MyDrive/DeepLearningECG/artifacts/"

    else:
        # Case 3: Local fallback (if running outside Colab)
        DATA_PATH = "../DeepLearningECG/data/"
        ARTIFACT_DIR = "../DeepLearningECG/artifacts/"


# Path where the WFDB ECG files (.hea/.dat) live.
ECG_DIR = os.path.join(DATA_PATH, "Child_ecg/")

# Output directory for training results
RESULTS_DIR = os.path.join(ARTIFACT_DIR, "training_results")
os.makedirs(RESULTS_DIR, exist_ok=True)

print("DATA_PATH:", DATA_PATH)
print("ARTIFACT_DIR:", ARTIFACT_DIR)
print("ECG_DIR:", ECG_DIR)
print("RESULTS_DIR:", RESULTS_DIR)
print("Available artifacts:", os.listdir(ARTIFACT_DIR))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 21 files:   0%|          | 0/21 [00:00<?, ?it/s]
# artifacts/training_results/baseline_mode(…):   0%|          | 0.00/8.29M [00:00<?, ?B/s]
# artifacts/training_results/baseline_mode(…):   0%|          | 0.00/8.28M [00:00<?, ?B/s]
# artifacts/X_windows.npy:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/374 [00:00<?, ?B/s]
# label_mapping.json: 0.00B [00:00, ?B/s]
# qc_summary.csv: 0.00B [00:00, ?B/s]
# Test:   0%|          | 0.00/4.00 [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# artifacts/training_results/confusion_mat(…):   0%|          | 0.00/123k [00:00<?, ?B/s]
# artifacts/training_results/test_predicti(…):   0%|          | 0.00/588k [00:00<?, ?B/s]
# artifacts/training_results/training_hist(…):   0%|          | 0.00/108k [00:00<?, ?B/s]
# summary_report_20251122_105216.txt: 0.00B [00:00, ?B/s]
# training_history_20251122_105216.json: 0.00B [00:00, ?B/s]
# artifacts/y_labels.npy:   0%|          | 0.00/479k [00:00<?, ?B/s]
# training_results_20251122_105216.json: 0.00B [00:00, ?B/s]
# data/Child_ecg.z01:   0%|          | 0.00/2.15G [00:00<?, ?B/s]
# data/Child_ecg.zip:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# AttributesDictionary.csv: 0.00B [00:00, ?B/s]
# DiseaseCode.csv: 0.00B [00:00, ?B/s]
# ECGCode.csv: 0.00B [00:00, ?B/s]
# ExampleReadingCode.ipynb: 0.00B [00:00, ?B/s]
# Downloaded to: /content/ECG-database
# DATA_PATH: /content/ECG-database/data/
# ARTIFACT_DIR: /content/ECG-database/artifacts/
# ECG_DIR: /content/ECG-database/data/Child_ecg/
# RESULTS_DIR: /content/ECG-database/artifacts/training_results
# Available artifacts: ['X_windows.npy', 'label_mapping.json', 'Test', 'qc_summary.csv', 'training_results', 'y_labels.npy']

# %% [markdown]
# ### Step 3: Load Preprocessed Data and Metadata
# Load the ECG windows, labels, and QC information from the preprocessing step:
# - **X_windows.npy**: Preprocessed signal windows (shape: N_windows × 5000 × 12)
# - **y_labels.npy**: Integer labels for each window
# - **qc_summary.csv**: QC metrics and metadata per ECG record
# - **label_mapping.json**: Diagnosis code to integer mapping

# %%
# Load preprocessed data
X = np.load(os.path.join(ARTIFACT_DIR, "X_windows.npy"))
y = np.load(os.path.join(ARTIFACT_DIR, "y_labels.npy"))
df_qc = pd.read_csv(os.path.join(ARTIFACT_DIR, "qc_summary.csv"))

# Load label mapping
with open(os.path.join(ARTIFACT_DIR, "label_mapping.json"), "r") as f:
    label_mapping = json.load(f)

label_to_int = label_mapping["label_to_int"]
int_to_label = {int(k): v for k, v in label_mapping["int_to_label"].items()}

print("Data shapes:")
print(f"  X: {X.shape} (windows × time_samples × channels)")
print(f"  y: {y.shape}")
print(f"\nLabel distribution:")
unique, counts = np.unique(y, return_counts=True)
for label_idx, count in zip(unique, counts):
    diagnosis = int_to_label[int(label_idx)]
    print(f"  {diagnosis}: {count} windows ({100*count/len(y):.1f}%)")
print(f"\nNumber of unique diagnoses: {len(label_to_int)}")
# Out:
# Data shapes:
#   X: (59868, 5000, 1) (windows × time_samples × channels)
#   y: (59868,)
#
# Label distribution:
#   (F) I40.0: 372 windows (0.6%)
#   (FO) Q21.1: 2620 windows (4.4%)
#   (OSD) Q21.1: 396 windows (0.7%)
#   (V) I40.0: 1391 windows (2.3%)
#   A02.1: 3 windows (0.0%)
#   A02.9: 5 windows (0.0%)
#   A05.2: 5 windows (0.0%)
#   A08.0: 28 windows (0.0%)
#   A09.0: 10 windows (0.0%)
#   A09.9: 29 windows (0.0%)
#   A15.3: 4 windows (0.0%)
#   A16.2: 20 windows (0.0%)
#   A16.5: 5 windows (0.0%)
#   A16.9: 25 windows (0.0%)
#   A17.0: 22 windows (0.0%)
#   A17.8: 15 windows (0.0%)
#   A18.0: 18 windows (0.0%)
#   A18.3: 8 windows (0.0%)
#   A18.8: 5 windows (0.0%)
#   A23.9: 3 windows (0.0%)
#   A37.9: 14 windows (0.0%)
#   A41.0: 10 windows (0.0%)
#   A41.5: 2 windows (0.0%)
#   A41.9: 1263 windows (2.1%)
#   A46: 6 windows (0.0%)
#   A49.0: 10 windows (0.0%)
#   A49.1: 80 windows (0.1%)
#   A49.3: 306 windows (0.5%)
#   A49.8: 188 windows (0.3%)
#   A49.9: 58 windows (0.1%)
#   A71.9: 8 windows (0.0%)
#   A81.1: 5 windows (0.0%)
#   A86: 257 windows (0.4%)
#   A87.9: 32 windows (0.1%)
#   B00.8: 10 windows (0.0%)
#   B00.9: 31 windows (0.1%)
#   B01.9: 11 windows (0.0%)
#   B02.8: 5 windows (0.0%)
#   B02.9: 8 windows (0.0%)
#   B07: 9 windows (0.0%)
#   B08.5: 15 windows (0.0%)
#   B09: 8 windows (0.0%)
#   B16.9: 24 windows (0.0%)
#   B18.1: 13 windows (0.0%)
#   B18.2: 8 windows (0.0%)
#   B25.1: 5 windows (0.0%)
#   B25.9: 52 windows (0.1%)
#   B27.9: 36 windows (0.1%)
#   B30.9: 13 windows (0.0%)
#   B33.2: 5 windows (0.0%)
#   B34.0: 35 windows (0.1%)
#   B34.1: 10 windows (0.0%)
#   B34.8: 38 windows (0.1%)
#   B34.9: 22 windows (0.0%)
#   B35.0: 27 windows (0.0%)
#   B35.2: 5 windows (0.0%)
#   B35.6: 3 windows (0.0%)
#   B36.0: 2 windows (0.0%)
#   B37.0: 15 windows (0.0%)
#   B45.1: 20 windows (0.0%)
#   B49: 195 windows (0.3%)
#   B55.0: 5 windows (0.0%)
#   B59: 5 windows (0.0%)
#   B77.8: 5 windows (0.0%)
#   B82.9: 8 windows (0.0%)
#   B83.0: 27 windows (0.0%)
#   B86: 5 windows (0.0%)
#   B94.1: 15 windows (0.0%)
#   B99: 122 windows (0.2%)
#   C02.9: 5 windows (0.0%)
#   C06.9: 5 windows (0.0%)
#   C07: 8 windows (0.0%)
#   C11.9: 10 windows (0.0%)
#   C22.2: 8 windows (0.0%)
#   C22.9: 5 windows (0.0%)
#   C25.0: 3 windows (0.0%)
#   C25.1: 5 windows (0.0%)
#   C25.9: 12 windows (0.0%)
#   C34.2: 5 windows (0.0%)
#   C38.2: 10 windows (0.0%)
#   C38.3: 33 windows (0.1%)
#   C40.0: 3 windows (0.0%)
#   C40.2: 11 windows (0.0%)
#   C41.0: 10 windows (0.0%)
#   C41.1: 10 windows (0.0%)
#   C41.4: 5 windows (0.0%)
#   C44.1: 5 windows (0.0%)
#   C47.5: 3 windows (0.0%)
#   C48.0: 10 windows (0.0%)
#   C48.2: 10 windows (0.0%)
#   C49.2: 3 windows (0.0%)
#   C49.3: 8 windows (0.0%)
#   C49.9: 10 windows (0.0%)
#   C52: 3 windows (0.0%)
#   C54.1: 5 windows (0.0%)
#   C56: 8 windows (0.0%)
#   C61: 5 windows (0.0%)
#   C62.9: 5 windows (0.0%)
#   C64: 18 windows (0.0%)
#   C69.2: 5 windows (0.0%)
#   C69.6: 5 windows (0.0%)
#   C69.9: 5 windows (0.0%)
#   C71.0: 13 windows (0.0%)
#   C71.1: 31 windows (0.1%)
#   C71.2: 30 windows (0.1%)
#   C71.3: 3 windows (0.0%)
#   C71.5: 50 windows (0.1%)
#   C71.6: 70 windows (0.1%)
#   C71.7: 58 windows (0.1%)
#   C71.8: 7 windows (0.0%)
#   C71.9: 89 windows (0.1%)
#   C73: 35 windows (0.1%)
#   C74.9: 18 windows (0.0%)
#   C75.2: 10 windows (0.0%)
#   C75.3: 13 windows (0.0%)
#   C76.0: 5 windows (0.0%)
#   C76.1: 7 windows (0.0%)
#   C76.3: 13 windows (0.0%)
#   C76.4: 1 windows (0.0%)
#   C76.5: 5 windows (0.0%)
#   C77.0: 5 windows (0.0%)
#   C79.4: 19 windows (0.0%)
#   C79.5: 5 windows (0.0%)
#   C79.8: 3 windows (0.0%)
#   C81.9: 13 windows (0.0%)
#   C83.3: 5 windows (0.0%)
#   C83.7: 49 windows (0.1%)
#   C85.1: 18 windows (0.0%)
#   C85.7: 5 windows (0.0%)
#   C85.9: 54 windows (0.1%)
#   C90.2: 5 windows (0.0%)
#   C91.0: 215 windows (0.4%)
#   C92.0: 95 windows (0.2%)
#   C92.1: 27 windows (0.0%)
#   C92.4: 37 windows (0.1%)
#   C92.7: 5 windows (0.0%)
#   C93.0: 63 windows (0.1%)
#   C94.0: 10 windows (0.0%)
#   C95.0: 29 windows (0.0%)
#   C95.7: 10 windows (0.0%)
#   C95.9: 5 windows (0.0%)
#   C96.7: 2 windows (0.0%)
#   D10.0: 5 windows (0.0%)
#   D10.1: 10 windows (0.0%)
#   D10.3: 5 windows (0.0%)
#   D10.5: 3 windows (0.0%)
#   D10.9: 11 windows (0.0%)
#   D11.0: 25 windows (0.0%)
#   D11.7: 6 windows (0.0%)
#   D12.6: 5 windows (0.0%)
#   D13.4: 10 windows (0.0%)
#   D13.6: 5 windows (0.0%)
#   D14.0: 16 windows (0.0%)
#   D14.1: 27 windows (0.0%)
#   D14.3: 10 windows (0.0%)
#   D15.1: 5 windows (0.0%)
#   D15.2: 24 windows (0.0%)
#   D16.0: 11 windows (0.0%)
#   D16.1: 34 windows (0.1%)
#   D16.2: 160 windows (0.3%)
#   D16.3: 17 windows (0.0%)
#   D16.4: 10 windows (0.0%)
#   D16.5: 33 windows (0.1%)
#   D16.8: 5 windows (0.0%)
#   D17.0: 5 windows (0.0%)
#   D17.1: 3 windows (0.0%)
#   D17.2: 3 windows (0.0%)
#   D17.4: 3 windows (0.0%)
#   D17.7: 3 windows (0.0%)
#   D18.0: 285 windows (0.5%)
#   D18.1: 48 windows (0.1%)
#   D20.0: 13 windows (0.0%)
#   D21.2: 10 windows (0.0%)
#   D22.0: 8 windows (0.0%)
#   D22.1: 8 windows (0.0%)
#   D22.2: 8 windows (0.0%)
#   D22.3: 171 windows (0.3%)
#   D22.4: 41 windows (0.1%)
#   D22.5: 61 windows (0.1%)
#   D22.6: 42 windows (0.1%)
#   D22.7: 45 windows (0.1%)
#   D22.9: 61 windows (0.1%)
#   D23.1: 5 windows (0.0%)
#   D23.3: 28 windows (0.0%)
#   D23.4: 49 windows (0.1%)
#   D23.5: 2 windows (0.0%)
#   D23.6: 15 windows (0.0%)
#   D23.9: 3 windows (0.0%)
#   D24: 99 windows (0.2%)
#   D25.9: 6 windows (0.0%)
#   D27: 95 windows (0.2%)
#   D28.2: 3 windows (0.0%)
#   D31.1: 10 windows (0.0%)
#   D31.3: 3 windows (0.0%)
#   D31.6: 6 windows (0.0%)
#   D32.0: 5 windows (0.0%)
#   D33.0: 10 windows (0.0%)
#   D33.2: 15 windows (0.0%)
#   D35.0: 20 windows (0.0%)
#   D35.2: 42 windows (0.1%)
#   D35.3: 5 windows (0.0%)
#   D36.1: 6 windows (0.0%)
#   D36.7: 111 windows (0.2%)
#   D37.0: 10 windows (0.0%)
#   D37.7: 10 windows (0.0%)
#   D38.3: 30 windows (0.1%)
#   D39.1: 18 windows (0.0%)
#   D40.1: 6 windows (0.0%)
#   D43.0: 16 windows (0.0%)
#   D43.1: 20 windows (0.0%)
#   D43.2: 17 windows (0.0%)
#   D43.4: 3 windows (0.0%)
#   D44.0: 3 windows (0.0%)
#   D44.1: 16 windows (0.0%)
#   D44.3: 5 windows (0.0%)
#   D44.4: 89 windows (0.1%)
#   D44.5: 5 windows (0.0%)
#   D46.9: 10 windows (0.0%)
#   D47.7: 35 windows (0.1%)
#   D48.0: 17 windows (0.0%)
#   D48.1: 16 windows (0.0%)
#   D48.3: 3 windows (0.0%)
#   D48.5: 7 windows (0.0%)
#   D48.6: 15 windows (0.0%)
#   D48.7: 43 windows (0.1%)
#   D50.0: 5 windows (0.0%)
#   D50.8: 9 windows (0.0%)
#   D50.9: 52 windows (0.1%)
#   D51.1: 5 windows (0.0%)
#   D52.0: 3 windows (0.0%)
#   D53.1: 5 windows (0.0%)
#   D53.8: 5 windows (0.0%)
#   D53.9: 5 windows (0.0%)
#   D56.9: 20 windows (0.0%)
#   D58.0: 61 windows (0.1%)
#   D58.9: 23 windows (0.0%)
#   D59.1: 13 windows (0.0%)
#   D59.3: 54 windows (0.1%)
#   D60.9: 5 windows (0.0%)
#   D61.1: 2 windows (0.0%)
#   D61.8: 10 windows (0.0%)
#   D61.9: 170 windows (0.3%)
#   D62: 37 windows (0.1%)
#   D64.9: 1569 windows (2.6%)
#   D65: 111 windows (0.2%)
#   D66: 18 windows (0.0%)
#   D68.1: 7 windows (0.0%)
#   D68.2: 2 windows (0.0%)
#   D68.6: 22 windows (0.0%)
#   D68.9: 509 windows (0.9%)
#   D69.0: 669 windows (1.1%)
#   D69.1: 3 windows (0.0%)
#   D69.3: 5 windows (0.0%)
#   D69.4: 170 windows (0.3%)
#   D69.6: 30 windows (0.1%)
#   D69.8: 4 windows (0.0%)
#   D70: 217 windows (0.4%)
#   D72.1: 26 windows (0.0%)
#   D72.8: 8 windows (0.0%)
#   D73.1: 18 windows (0.0%)
#   D75.2: 24 windows (0.0%)
#   D75.8: 5 windows (0.0%)
#   D76.0: 5 windows (0.0%)
#   D76.1: 80 windows (0.1%)
#   D80.1: 5 windows (0.0%)
#   D80.9: 5 windows (0.0%)
#   D82.1: 17 windows (0.0%)
#   D82.8: 10 windows (0.0%)
#   D84.9: 17 windows (0.0%)
#   D86.0: 48 windows (0.1%)
#   D86.8: 5 windows (0.0%)
#   E02: 24 windows (0.0%)
#   E03.1: 9 windows (0.0%)
#   E03.8: 37 windows (0.1%)
#   E03.9: 85 windows (0.1%)
#   E04.1: 904 windows (1.5%)
#   E04.9: 25 windows (0.0%)
#   E05.0: 48 windows (0.1%)
#   E05.2: 5 windows (0.0%)
#   E05.5: 10 windows (0.0%)
#   E05.8: 5 windows (0.0%)
#   E05.9: 72 windows (0.1%)
#   E06.0: 8 windows (0.0%)
#   E06.3: 29 windows (0.0%)
#   E06.9: 5 windows (0.0%)
#   E07.8: 10 windows (0.0%)
#   E10.1: 62 windows (0.1%)
#   E10.8: 5 windows (0.0%)
#   E10.9: 30 windows (0.1%)
#   E11.0: 2 windows (0.0%)
#   E11.9: 23 windows (0.0%)
#   E13.9: 62 windows (0.1%)
#   E14.1: 12 windows (0.0%)
#   E14.9: 16 windows (0.0%)
#   E16.1: 29 windows (0.0%)
#   E16.2: 24 windows (0.0%)
#   E16.8: 28 windows (0.0%)
#   E20.0: 5 windows (0.0%)
#   E20.1: 32 windows (0.1%)
#   E20.8: 5 windows (0.0%)
#   E20.9: 46 windows (0.1%)
#   E21.1: 28 windows (0.0%)
#   E22.1: 19 windows (0.0%)
#   E22.8: 13 windows (0.0%)
#   E23.0: 96 windows (0.2%)
#   E23.2: 87 windows (0.1%)
#   E23.6: 42 windows (0.1%)
#   E24.9: 5 windows (0.0%)
#   E25.0: 27 windows (0.0%)
#   E26.8: 10 windows (0.0%)
#   E26.9: 10 windows (0.0%)
#   E27.0: 15 windows (0.0%)
#   E27.1: 5 windows (0.0%)
#   E27.2: 5 windows (0.0%)
#   E27.8: 40 windows (0.1%)
#   E27.9: 8 windows (0.0%)
#   E28.2: 15 windows (0.0%)
#   E29.1: 5 windows (0.0%)
#   E30.0: 29 windows (0.0%)
#   E30.1: 10 windows (0.0%)
#   E30.8: 12 windows (0.0%)
#   E32.0: 13 windows (0.0%)
#   E34.3: 96 windows (0.2%)
#   E34.8: 10 windows (0.0%)
#   E34.9: 2 windows (0.0%)
#   E41: 68 windows (0.1%)
#   E44.0: 23 windows (0.0%)
#   E44.1: 32 windows (0.1%)
#   E46: 155 windows (0.3%)
#   E53.8: 8 windows (0.0%)
#   E55.9: 49 windows (0.1%)
#   E65: 5 windows (0.0%)
#   E66.9: 144 windows (0.2%)
#   E71.1: 19 windows (0.0%)
#   E71.3: 5 windows (0.0%)
#   E72.1: 63 windows (0.1%)
#   E72.2: 15 windows (0.0%)
#   E74.8: 66 windows (0.1%)
#   E74.9: 12 windows (0.0%)
#   E76.2: 4 windows (0.0%)
#   E76.3: 5 windows (0.0%)
#   E77.8: 216 windows (0.4%)
#   E78.5: 15 windows (0.0%)
#   E79.0: 15 windows (0.0%)
#   E80.6: 8 windows (0.0%)
#   E83.0: 12 windows (0.0%)
#   E83.1: 16 windows (0.0%)
#   E83.3: 17 windows (0.0%)
#   E83.5: 37 windows (0.1%)
#   E86: 59 windows (0.1%)
#   E87.0: 8 windows (0.0%)
#   E87.1: 61 windows (0.1%)
#   E87.2: 176 windows (0.3%)
#   E87.3: 26 windows (0.0%)
#   E87.4: 15 windows (0.0%)
#   E87.5: 14 windows (0.0%)
#   E87.6: 192 windows (0.3%)
#   E87.8: 517 windows (0.9%)
#   E88.2: 5 windows (0.0%)
#   E88.9: 21 windows (0.0%)
#   F05.0: 5 windows (0.0%)
#   F06.8: 10 windows (0.0%)
#   F07.2: 5 windows (0.0%)
#   F20.9: 107 windows (0.2%)
#   F23.9: 5 windows (0.0%)
#   F30.9: 5 windows (0.0%)
#   F31.4: 15 windows (0.0%)
#   F31.5: 2 windows (0.0%)
#   F31.7: 5 windows (0.0%)
#   F31.8: 25 windows (0.0%)
#   F31.9: 9 windows (0.0%)
#   F32.2: 118 windows (0.2%)
#   F32.3: 100 windows (0.2%)
#   F32.9: 138 windows (0.2%)
#   F39: 3 windows (0.0%)
#   F41.0: 5 windows (0.0%)
#   F41.1: 13 windows (0.0%)
#   F41.2: 53 windows (0.1%)
#   F41.3: 5 windows (0.0%)
#   F41.9: 23 windows (0.0%)
#   F42.0: 5 windows (0.0%)
#   F42.9: 37 windows (0.1%)
#   F44.9: 69 windows (0.1%)
#   F45.0: 12 windows (0.0%)
#   F45.3: 5 windows (0.0%)
#   F45.8: 5 windows (0.0%)
#   F45.9: 10 windows (0.0%)
#   F48.9: 8 windows (0.0%)
#   F50.0: 4 windows (0.0%)
#   F51.4: 5 windows (0.0%)
#   F59: 15 windows (0.0%)
#   F79.0: 10 windows (0.0%)
#   F79.1: 8 windows (0.0%)
#   F79.9: 61 windows (0.1%)
#   F80.9: 5 windows (0.0%)
#   F84.0: 8 windows (0.0%)
#   F93.9: 138 windows (0.2%)
#   F95.9: 51 windows (0.1%)
#   F98.0: 10 windows (0.0%)
#   F98.8: 40 windows (0.1%)
#   F98.9: 52 windows (0.1%)
#   F99: 81 windows (0.1%)
#   G00.2: 10 windows (0.0%)
#   G00.9: 37 windows (0.1%)
#   G03.0: 10 windows (0.0%)
#   G03.9: 12 windows (0.0%)
#   G04.0: 23 windows (0.0%)
#   G04.8: 60 windows (0.1%)
#   G04.9: 61 windows (0.1%)
#   G06.0: 67 windows (0.1%)
#   G08: 3 windows (0.0%)
#   G09: 5 windows (0.0%)
#   G11.4: 5 windows (0.0%)
#   G11.9: 5 windows (0.0%)
#   G24.9: 62 windows (0.1%)
#   G25.5: 5 windows (0.0%)
#   G25.8: 5 windows (0.0%)
#   G25.9: 5 windows (0.0%)
#   G31.8: 5 windows (0.0%)
#   G31.9: 14 windows (0.0%)
#   G36.0: 10 windows (0.0%)
#   G37.3: 5 windows (0.0%)
#   G37.8: 5 windows (0.0%)
#   G37.9: 20 windows (0.0%)
#   G40.0: 5 windows (0.0%)
#   G40.3: 10 windows (0.0%)
#   G40.4: 15 windows (0.0%)
#   G40.5: 3 windows (0.0%)
#   G40.6: 5 windows (0.0%)
#   G40.8: 111 windows (0.2%)
#   G40.9: 565 windows (0.9%)
#   G41.8: 3 windows (0.0%)
#   G41.9: 73 windows (0.1%)
#   G43.0: 4 windows (0.0%)
#   G43.9: 47 windows (0.1%)
#   G44.1: 50 windows (0.1%)
#   G44.2: 5 windows (0.0%)
#   G45.9: 5 windows (0.0%)
#   G47.3: 8 windows (0.0%)
#   G47.4: 25 windows (0.0%)
#   G47.9: 17 windows (0.0%)
#   G51.0: 45 windows (0.1%)
#   G51.8: 5 windows (0.0%)
#   G52.2: 10 windows (0.0%)
#   G52.9: 3 windows (0.0%)
#   G54.1: 3 windows (0.0%)
#   G56.2: 5 windows (0.0%)
#   G56.3: 8 windows (0.0%)
#   G57.3: 14 windows (0.0%)
#   G60.0: 5 windows (0.0%)
#   G60.9: 5 windows (0.0%)
#   G61.0: 11 windows (0.0%)
#   G62.9: 10 windows (0.0%)
#   G70.0: 20 windows (0.0%)
#   G70.9: 15 windows (0.0%)
#   G71.0: 82 windows (0.1%)
#   G71.3: 10 windows (0.0%)
#   G72.3: 5 windows (0.0%)
#   G72.9: 5 windows (0.0%)
#   G80.1: 5 windows (0.0%)
#   G80.9: 16 windows (0.0%)
#   G81.9: 25 windows (0.0%)
#   G82.2: 28 windows (0.0%)
#   G90.0: 4 windows (0.0%)
#   G90.9: 10 windows (0.0%)
#   G91.0: 10 windows (0.0%)
#   G91.1: 19 windows (0.0%)
#   G91.8: 7 windows (0.0%)
#   G91.9: 64 windows (0.1%)
#   G92: 10 windows (0.0%)
#   G93.0: 86 windows (0.1%)
#   G93.1: 42 windows (0.1%)
#   G93.2: 5 windows (0.0%)
#   G93.4: 71 windows (0.1%)
#   G93.5: 49 windows (0.1%)
#   G93.6: 5 windows (0.0%)
#   G93.8: 41 windows (0.1%)
#   G93.9: 15 windows (0.0%)
#   G95.0: 6 windows (0.0%)
#   G95.1: 3 windows (0.0%)
#   G95.8: 9 windows (0.0%)
#   G95.9: 23 windows (0.0%)
#   G96.0: 33 windows (0.1%)
#   G96.1: 2 windows (0.0%)
#   G96.9: 10 windows (0.0%)
#   G97.8: 2 windows (0.0%)
#   H00.0: 14 windows (0.0%)
#   H00.1: 15 windows (0.0%)
#   H01.0: 2 windows (0.0%)
#   H01.8: 2 windows (0.0%)
#   H01.9: 3 windows (0.0%)
#   H02.0: 133 windows (0.2%)
#   H02.3: 5 windows (0.0%)
#   H02.4: 220 windows (0.4%)
#   H02.5: 5 windows (0.0%)
#   H02.8: 25 windows (0.0%)
#   H02.9: 32 windows (0.1%)
#   H04.4: 5 windows (0.0%)
#   H04.5: 12 windows (0.0%)
#   H04.8: 26 windows (0.0%)
#   H04.9: 5 windows (0.0%)
#   H05.0: 30 windows (0.1%)
#   H05.1: 5 windows (0.0%)
#   H05.2: 9 windows (0.0%)
#   H05.8: 4 windows (0.0%)
#   H05.9: 44 windows (0.1%)
#   H10.9: 8 windows (0.0%)
#   H11.0: 5 windows (0.0%)
#   H11.1: 4 windows (0.0%)
#   H11.3: 5 windows (0.0%)
#   H11.8: 5 windows (0.0%)
#   H11.9: 27 windows (0.0%)
#   H16.0: 5 windows (0.0%)
#   H16.9: 10 windows (0.0%)
#   H17.8: 13 windows (0.0%)
#   H18.4: 8 windows (0.0%)
#   H18.6: 10 windows (0.0%)
#   H18.8: 5 windows (0.0%)
#   H20.0: 5 windows (0.0%)
#   H20.9: 58 windows (0.1%)
#   H21.0: 29 windows (0.0%)
#   H21.4: 12 windows (0.0%)
#   H21.5: 53 windows (0.1%)
#   H26.1: 82 windows (0.1%)
#   H26.2: 13 windows (0.0%)
#   H26.4: 12 windows (0.0%)
#   H26.9: 98 windows (0.2%)
#   H27.0: 85 windows (0.1%)
#   H27.1: 58 windows (0.1%)
#   H31.1: 2 windows (0.0%)
#   H31.4: 5 windows (0.0%)
#   H31.8: 10 windows (0.0%)
#   H33.1: 14 windows (0.0%)
#   H33.2: 49 windows (0.1%)
#   H33.3: 3 windows (0.0%)
#   H33.5: 16 windows (0.0%)
#   H34.2: 5 windows (0.0%)
#   H35.0: 41 windows (0.1%)
#   H35.1: 26 windows (0.0%)
#   H35.3: 26 windows (0.0%)
#   H35.6: 8 windows (0.0%)
#   H40.0: 25 windows (0.0%)
#   H40.1: 5 windows (0.0%)
#   H40.3: 5 windows (0.0%)
#   H40.5: 5 windows (0.0%)
#   H40.8: 5 windows (0.0%)
#   H40.9: 20 windows (0.0%)
#   H43.1: 18 windows (0.0%)
#   H44.0: 1 windows (0.0%)
#   H44.2: 5 windows (0.0%)
#   H44.4: 5 windows (0.0%)
#   H44.8: 5 windows (0.0%)
#   H44.9: 8 windows (0.0%)
#   H46: 68 windows (0.1%)
#   H47.0: 31 windows (0.1%)
#   H47.2: 22 windows (0.0%)
#   H49.8: 28 windows (0.0%)
#   H50.0: 250 windows (0.4%)
#   H50.1: 328 windows (0.5%)
#   H50.2: 44 windows (0.1%)
#   H50.3: 343 windows (0.6%)
#   H50.4: 3 windows (0.0%)
#   H50.5: 5 windows (0.0%)
#   H50.8: 6 windows (0.0%)
#   H50.9: 61 windows (0.1%)
#   H52.1: 10 windows (0.0%)
#   H52.3: 5 windows (0.0%)
#   H52.5: 5 windows (0.0%)
#   H52.7: 24 windows (0.0%)
#   H53.0: 17 windows (0.0%)
#   H53.2: 2 windows (0.0%)
#   H54.6: 10 windows (0.0%)
#   H54.9: 5 windows (0.0%)
#   H55: 4 windows (0.0%)
#   H57.1: 3 windows (0.0%)
#   H57.9: 5 windows (0.0%)
#   H60.0: 3 windows (0.0%)
#   H60.3: 13 windows (0.0%)
#   H60.4: 49 windows (0.1%)
#   H60.9: 19 windows (0.0%)
#   H61.0: 3 windows (0.0%)
#   H61.1: 6 windows (0.0%)
#   H61.2: 16 windows (0.0%)
#   H61.8: 43 windows (0.1%)
#   H61.9: 16 windows (0.0%)
#   H65.0: 53 windows (0.1%)
#   H65.3: 1 windows (0.0%)
#   H65.9: 397 windows (0.7%)
#   H66.0: 18 windows (0.0%)
#   H66.3: 32 windows (0.1%)
#   H66.4: 8 windows (0.0%)
#   H66.9: 240 windows (0.4%)
#   H69.9: 3 windows (0.0%)
#   H70.0: 6 windows (0.0%)
#   H70.1: 3 windows (0.0%)
#   H70.9: 25 windows (0.0%)
#   H71: 91 windows (0.2%)
#   H72.9: 16 windows (0.0%)
#   H73.8: 5 windows (0.0%)
#   H80.2: 2 windows (0.0%)
#   H81.0: 3 windows (0.0%)
#   H81.3: 12 windows (0.0%)
#   H81.9: 8 windows (0.0%)
#   H90.2: 18 windows (0.0%)
#   H90.3: 30 windows (0.1%)
#   H90.5: 356 windows (0.6%)
#   H91.2: 75 windows (0.1%)
#   H91.9: 9 windows (0.0%)
#   H92.1: 5 windows (0.0%)
#   H93.1: 3 windows (0.0%)
#   H93.2: 3 windows (0.0%)
#   H93.9: 15 windows (0.0%)
#   I05.0: 5 windows (0.0%)
#   I05.2: 8 windows (0.0%)
#   I05.9: 10 windows (0.0%)
#   I07.1: 1400 windows (2.3%)
#   I07.8: 10 windows (0.0%)
#   I07.9: 13 windows (0.0%)
#   I08.0: 3 windows (0.0%)
#   I08.1: 96 windows (0.2%)
#   I08.2: 10 windows (0.0%)
#   I08.3: 3 windows (0.0%)
#   I10: 96 windows (0.2%)
#   I15.1: 15 windows (0.0%)
#   I15.9: 17 windows (0.0%)
#   I20.1: 3 windows (0.0%)
#   I24.0: 15 windows (0.0%)
#   I25.4: 85 windows (0.1%)
#   I25.8: 30 windows (0.1%)
#   I26.9: 5 windows (0.0%)
#   I27.0: 256 windows (0.4%)
#   I27.2: 594 windows (1.0%)
#   I30.1: 5 windows (0.0%)
#   I30.9: 7 windows (0.0%)
#   I31.1: 10 windows (0.0%)
#   I31.3: 5 windows (0.0%)
#   I31.8: 180 windows (0.3%)
#   I34.0: 145 windows (0.2%)
#   I34.1: 38 windows (0.1%)
#   I34.8: 5 windows (0.0%)
#   I35.0: 55 windows (0.1%)
#   I35.1: 60 windows (0.1%)
#   I35.2: 3 windows (0.0%)
#   I36.8: 25 windows (0.0%)
#   I37.0: 175 windows (0.3%)
#   I37.1: 25 windows (0.0%)
#   I37.2: 10 windows (0.0%)
#   I38: 23 windows (0.0%)
#   I40.9: 313 windows (0.5%)
#   I42.0: 176 windows (0.3%)
#   I42.1: 5 windows (0.0%)
#   I42.2: 48 windows (0.1%)
#   I42.4: 58 windows (0.1%)
#   I42.8: 20 windows (0.0%)
#   I42.9: 33 windows (0.1%)
#   I44.1: 18 windows (0.0%)
#   I44.2: 88 windows (0.1%)
#   I44.3: 294 windows (0.5%)
#   I44.4: 11 windows (0.0%)
#   I44.5: 5 windows (0.0%)
#   I44.7: 3 windows (0.0%)
#   I45.1: 31 windows (0.1%)
#   I45.6: 248 windows (0.4%)
#   I45.8: 65 windows (0.1%)
#   I46.0: 3 windows (0.0%)
#   I46.9: 27 windows (0.0%)
#   I47.1: 438 windows (0.7%)
#   I47.2: 111 windows (0.2%)
#   I47.9: 10 windows (0.0%)
#   I48: 24 windows (0.0%)
#   I49.1: 80 windows (0.1%)
#   I49.3: 320 windows (0.5%)
#   I49.4: 23 windows (0.0%)
#   I49.5: 5 windows (0.0%)
#   I49.8: 69 windows (0.1%)
#   I49.9: 232 windows (0.4%)
#   I50.0: 10 windows (0.0%)
#   I50.1: 5 windows (0.0%)
#   I50.9: 563 windows (0.9%)
#   I51.4: 347 windows (0.6%)
#   I51.7: 33 windows (0.1%)
#   I51.9: 50 windows (0.1%)
#   I60.9: 10 windows (0.0%)
#   I61.0: 5 windows (0.0%)
#   I61.1: 49 windows (0.1%)
#   I61.5: 5 windows (0.0%)
#   I61.9: 59 windows (0.1%)
#   I62.0: 59 windows (0.1%)
#   I62.1: 65 windows (0.1%)
#   I62.9: 15 windows (0.0%)
#   I63.9: 25 windows (0.0%)
#   I65.2: 5 windows (0.0%)
#   I67.1: 14 windows (0.0%)
#   I67.4: 5 windows (0.0%)
#   I67.5: 23 windows (0.0%)
#   I69.0: 10 windows (0.0%)
#   I69.1: 15 windows (0.0%)
#   I69.8: 9 windows (0.0%)
#   I71.0: 3 windows (0.0%)
#   I71.2: 10 windows (0.0%)
#   I71.4: 5 windows (0.0%)
#   I72.0: 8 windows (0.0%)
#   I77.0: 8 windows (0.0%)
#   I77.1: 15 windows (0.0%)
#   I77.2: 3 windows (0.0%)
#   I77.6: 18 windows (0.0%)
#   I78.8: 31 windows (0.1%)
#   I80.3: 30 windows (0.1%)
#   I82.2: 5 windows (0.0%)
#   I82.3: 5 windows (0.0%)
#   I82.9: 5 windows (0.0%)
#   I86.1: 117 windows (0.2%)
#   I86.8: 5 windows (0.0%)
#   I87.1: 52 windows (0.1%)
#   I87.8: 3 windows (0.0%)
#   I88.0: 4 windows (0.0%)
#   I88.9: 37 windows (0.1%)
#   I89.0: 5 windows (0.0%)
#   I89.1: 5 windows (0.0%)
#   I95.1: 5 windows (0.0%)
#   I97.8: 15 windows (0.0%)
#   J01.9: 23 windows (0.0%)
#   J02.9: 11 windows (0.0%)
#   J03.9: 115 windows (0.2%)
#   J04.0: 27 windows (0.0%)
#   J06.9: 383 windows (0.6%)
#   J10.1: 25 windows (0.0%)
#   J11.1: 8 windows (0.0%)
#   J12.1: 5 windows (0.0%)
#   J15.7: 188 windows (0.3%)
#   J15.8: 10 windows (0.0%)
#   J15.9: 25 windows (0.0%)
#   J18.0: 207 windows (0.3%)
#   J18.1: 74 windows (0.1%)
#   J18.9: 1003 windows (1.7%)
#   J20.9: 18 windows (0.0%)
#   J21.9: 8 windows (0.0%)
#   J30.4: 124 windows (0.2%)
#   J31.0: 509 windows (0.9%)
#   J31.2: 13 windows (0.0%)
#   J32.0: 52 windows (0.1%)
#   J32.1: 3 windows (0.0%)
#   J32.2: 5 windows (0.0%)
#   J32.3: 7 windows (0.0%)
#   J32.4: 11 windows (0.0%)
#   J32.8: 15 windows (0.0%)
#   J32.9: 744 windows (1.2%)
#   J33.0: 8 windows (0.0%)
#   J33.8: 8 windows (0.0%)
#   J33.9: 11 windows (0.0%)
#   J34.1: 86 windows (0.1%)
#   J34.2: 128 windows (0.2%)
#   J34.3: 278 windows (0.5%)
#   J34.8: 10 windows (0.0%)
#   J35.0: 473 windows (0.8%)
#   J35.1: 531 windows (0.9%)
#   J35.2: 163 windows (0.3%)
#   J35.3: 442 windows (0.7%)
#   J37.0: 5 windows (0.0%)
#   J38.0: 3 windows (0.0%)
#   J38.1: 15 windows (0.0%)
#   J38.2: 8 windows (0.0%)
#   J38.7: 5 windows (0.0%)
#   J39.2: 15 windows (0.0%)
#   J39.8: 10 windows (0.0%)
#   J40: 48 windows (0.1%)
#   J42: 5 windows (0.0%)
#   J43.9: 77 windows (0.1%)
#   J45.0: 5 windows (0.0%)
#   J45.9: 50 windows (0.1%)
#   J46: 5 windows (0.0%)
#   J47: 13 windows (0.0%)
#   J84.9: 10 windows (0.0%)
#   J85.1: 5 windows (0.0%)
#   J86.0: 15 windows (0.0%)
#   J90: 5 windows (0.0%)
#   J92.9: 10 windows (0.0%)
#   J93.9: 48 windows (0.1%)
#   J94.2: 11 windows (0.0%)
#   J94.8: 63 windows (0.1%)
#   J95.0: 10 windows (0.0%)
#   J96.0: 1 windows (0.0%)
#   J96.9: 20 windows (0.0%)
#   J98.2: 5 windows (0.0%)
#   J98.4: 372 windows (0.6%)
#   J98.5: 3 windows (0.0%)
#   J98.6: 5 windows (0.0%)
#   J98.8: 156 windows (0.3%)
#   K00.1: 35 windows (0.1%)
#   K00.2: 3 windows (0.0%)
#   K00.3: 5 windows (0.0%)
#   K00.6: 10 windows (0.0%)
#   K01.0: 75 windows (0.1%)
#   K01.1: 28 windows (0.0%)
#   K02.4: 2 windows (0.0%)
#   K02.9: 15 windows (0.0%)
#   K06.8: 8 windows (0.0%)
#   K06.9: 13 windows (0.0%)
#   K07.0: 5 windows (0.0%)
#   K07.3: 15 windows (0.0%)
#   K07.5: 8 windows (0.0%)
#   K07.6: 30 windows (0.1%)
#   K08.1: 3 windows (0.0%)
#   K08.2: 5 windows (0.0%)
#   K08.8: 67 windows (0.1%)
#   K09.0: 15 windows (0.0%)
#   K09.1: 5 windows (0.0%)
#   K09.2: 155 windows (0.3%)
#   K09.8: 5 windows (0.0%)
#   K10.0: 5 windows (0.0%)
#   K10.2: 15 windows (0.0%)
#   K10.9: 10 windows (0.0%)
#   K11.2: 16 windows (0.0%)
#   K11.3: 10 windows (0.0%)
#   K11.4: 5 windows (0.0%)
#   K11.6: 98 windows (0.2%)
#   K11.9: 28 windows (0.0%)
#   K12.2: 55 windows (0.1%)
#   K13.0: 54 windows (0.1%)
#   K13.7: 30 windows (0.1%)
#   K14.0: 10 windows (0.0%)
#   K14.8: 28 windows (0.0%)
#   K14.9: 10 windows (0.0%)
#   K20: 15 windows (0.0%)
#   K21.0: 10 windows (0.0%)
#   K21.9: 3 windows (0.0%)
#   K22.0: 5 windows (0.0%)
#   K22.1: 5 windows (0.0%)
#   K22.2: 12 windows (0.0%)
#   K22.8: 10 windows (0.0%)
#   K22.9: 5 windows (0.0%)
#   K25.9: 16 windows (0.0%)
#   K26.9: 10 windows (0.0%)
#   K27.5: 5 windows (0.0%)
#   K29.1: 5 windows (0.0%)
#   K29.3: 52 windows (0.1%)
#   K29.5: 16 windows (0.0%)
#   K29.6: 30 windows (0.1%)
#   K29.7: 19 windows (0.0%)
#   K30: 13 windows (0.0%)
#   K31.5: 5 windows (0.0%)
#   K31.7: 6 windows (0.0%)
#   K35.0: 91 windows (0.2%)
#   K35.1: 19 windows (0.0%)
#   K35.9: 226 windows (0.4%)
#   K36: 27 windows (0.0%)
#   K37: 35 windows (0.1%)
#   K38.1: 10 windows (0.0%)
#   K40.2: 44 windows (0.1%)
#   K40.3: 15 windows (0.0%)
#   K40.9: 185 windows (0.3%)
#   K43.9: 9 windows (0.0%)
#   K51.9: 8 windows (0.0%)
#   K52.9: 26 windows (0.0%)
#   K55.0: 20 windows (0.0%)
#   K55.1: 17 windows (0.0%)
#   K56.1: 18 windows (0.0%)
#   K56.2: 15 windows (0.0%)
#   K56.5: 17 windows (0.0%)
#   K56.6: 5 windows (0.0%)
#   K56.7: 59 windows (0.1%)
#   K58.0: 5 windows (0.0%)
#   K59.0: 7 windows (0.0%)
#   K59.3: 8 windows (0.0%)
#   K60.3: 16 windows (0.0%)
#   K61.0: 22 windows (0.0%)
#   K62.1: 40 windows (0.1%)
#   K62.4: 3 windows (0.0%)
#   K62.6: 2 windows (0.0%)
#   K63.5: 7 windows (0.0%)
#   K63.9: 5 windows (0.0%)
#   K65.0: 16 windows (0.0%)
#   K65.8: 10 windows (0.0%)
#   K65.9: 10 windows (0.0%)
#   K66.0: 29 windows (0.0%)
#   K66.1: 4 windows (0.0%)
#   K66.8: 8 windows (0.0%)
#   K66.9: 5 windows (0.0%)
#   K71.9: 10 windows (0.0%)
#   K72.9: 12 windows (0.0%)
#   K74.1: 10 windows (0.0%)
#   K75.0: 5 windows (0.0%)
#   K75.9: 10 windows (0.0%)
#   K76.0: 42 windows (0.1%)
#   K76.6: 5 windows (0.0%)
#   K76.8: 11 windows (0.0%)
#   K76.9: 30 windows (0.1%)
#   K80.1: 5 windows (0.0%)
#   K80.2: 26 windows (0.0%)
#   K80.5: 10 windows (0.0%)
#   K81.1: 7 windows (0.0%)
#   K81.9: 5 windows (0.0%)
#   K82.8: 5 windows (0.0%)
#   K83.0: 8 windows (0.0%)
#   K83.1: 5 windows (0.0%)
#   K83.5: 23 windows (0.0%)
#   K83.8: 3 windows (0.0%)
#   K85.8: 5 windows (0.0%)
#   K85.9: 16 windows (0.0%)
#   K86.1: 10 windows (0.0%)
#   K86.3: 1 windows (0.0%)
#   K91.4: 3 windows (0.0%)
#   K91.8: 10 windows (0.0%)
#   K92.2: 42 windows (0.1%)
#   K92.9: 111 windows (0.2%)
#   L02.1: 49 windows (0.1%)
#   L02.2: 5 windows (0.0%)
#   L02.3: 10 windows (0.0%)
#   L02.4: 3 windows (0.0%)
#   L03.0: 17 windows (0.0%)
#   L03.1: 3 windows (0.0%)
#   L03.2: 5 windows (0.0%)
#   L03.8: 2 windows (0.0%)
#   L03.9: 5 windows (0.0%)
#   L04.9: 20 windows (0.0%)
#   L05.9: 7 windows (0.0%)
#   L08.8: 9 windows (0.0%)
#   L08.9: 79 windows (0.1%)
#   L20.9: 7 windows (0.0%)
#   L23.9: 8 windows (0.0%)
#   L27.0: 10 windows (0.0%)
#   L27.1: 2 windows (0.0%)
#   L28.0: 3 windows (0.0%)
#   L28.1: 2 windows (0.0%)
#   L28.2: 3 windows (0.0%)
#   L30.8: 3 windows (0.0%)
#   L30.9: 41 windows (0.1%)
#   L40.0: 14 windows (0.0%)
#   L40.4: 9 windows (0.0%)
#   L40.9: 37 windows (0.1%)
#   L41.0: 10 windows (0.0%)
#   L44.0: 3 windows (0.0%)
#   L50.8: 49 windows (0.1%)
#   L50.9: 50 windows (0.1%)
#   L51.8: 2 windows (0.0%)
#   L51.9: 4 windows (0.0%)
#   L53.8: 13 windows (0.0%)
#   L63.0: 4 windows (0.0%)
#   L63.1: 3 windows (0.0%)
#   L66.9: 5 windows (0.0%)
#   L70.0: 8 windows (0.0%)
#   L70.9: 3 windows (0.0%)
#   L72.0: 19 windows (0.0%)
#   L75.0: 10 windows (0.0%)
#   L80: 11 windows (0.0%)
#   L81.4: 5 windows (0.0%)
#   L81.7: 4 windows (0.0%)
#   L81.8: 3 windows (0.0%)
#   L85.1: 3 windows (0.0%)
#   L85.9: 67 windows (0.1%)
#   L90.5: 241 windows (0.4%)
#   L90.9: 9 windows (0.0%)
#   L91.0: 16 windows (0.0%)
#   L93.0: 9 windows (0.0%)
#   L93.1: 2 windows (0.0%)
#   L94.0: 12 windows (0.0%)
#   L94.1: 3 windows (0.0%)
#   L95.9: 8 windows (0.0%)
#   L98.4: 10 windows (0.0%)
#   L98.8: 13 windows (0.0%)
#   M00.9: 5 windows (0.0%)
#   M08.1: 14 windows (0.0%)
#   M08.8: 52 windows (0.1%)
#   M08.9: 15 windows (0.0%)
#   M10.9: 5 windows (0.0%)
#   M16.9: 6 windows (0.0%)
#   M17.9: 1 windows (0.0%)
#   M19.9: 5 windows (0.0%)
#   M20.0: 3 windows (0.0%)
#   M20.6: 3 windows (0.0%)
#   M21.0: 8 windows (0.0%)
#   M21.1: 8 windows (0.0%)
#   M21.2: 3 windows (0.0%)
#   M21.8: 3 windows (0.0%)
#   M22.0: 15 windows (0.0%)
#   M23.0: 5 windows (0.0%)
#   M23.1: 8 windows (0.0%)
#   M23.2: 5 windows (0.0%)
#   M23.3: 25 windows (0.0%)
#   M23.4: 12 windows (0.0%)
#   M24.2: 5 windows (0.0%)
#   M24.3: 8 windows (0.0%)
#   M24.6: 2 windows (0.0%)
#   M25.4: 79 windows (0.1%)
#   M25.5: 38 windows (0.1%)
#   M25.6: 10 windows (0.0%)
#   M25.8: 5 windows (0.0%)
#   M30.3: 313 windows (0.5%)
#   M31.0: 2 windows (0.0%)
#   M31.1: 2 windows (0.0%)
#   M32.1: 50 windows (0.1%)
#   M32.9: 26 windows (0.0%)
#   M33.1: 8 windows (0.0%)
#   M34.8: 10 windows (0.0%)
#   M35.2: 5 windows (0.0%)
#   M40.1: 5 windows (0.0%)
#   M40.2: 8 windows (0.0%)
#   M41.9: 157 windows (0.3%)
#   M43.0: 17 windows (0.0%)
#   M43.6: 66 windows (0.1%)
#   M45: 13 windows (0.0%)
#   M46.1: 10 windows (0.0%)
#   M46.8: 5 windows (0.0%)
#   M46.9: 5 windows (0.0%)
#   M47.9: 3 windows (0.0%)
#   M48.0: 3 windows (0.0%)
#   M48.3: 5 windows (0.0%)
#   M50.9: 5 windows (0.0%)
#   M51.2: 5 windows (0.0%)
#   M54.5: 4 windows (0.0%)
#   M60.0: 6 windows (0.0%)
#   M60.9: 15 windows (0.0%)
#   M61.5: 8 windows (0.0%)
#   M62.4: 18 windows (0.0%)
#   M62.8: 2 windows (0.0%)
#   M65.9: 56 windows (0.1%)
#   M67.0: 10 windows (0.0%)
#   M67.4: 5 windows (0.0%)
#   M71.2: 5 windows (0.0%)
#   M79.2: 4 windows (0.0%)
#   M79.3: 6 windows (0.0%)
#   M79.5: 5 windows (0.0%)
#   M79.6: 3 windows (0.0%)
#   M79.9: 4 windows (0.0%)
#   M84.1: 5 windows (0.0%)
#   M84.4: 18 windows (0.0%)
#   M85.0: 7 windows (0.0%)
#   M85.6: 15 windows (0.0%)
#   M86.9: 47 windows (0.1%)
#   M87.0: 8 windows (0.0%)
#   M87.1: 3 windows (0.0%)
#   M87.2: 5 windows (0.0%)
#   M89.8: 16 windows (0.0%)
#   M89.9: 104 windows (0.2%)
#   M93.9: 12 windows (0.0%)
#   M94.1: 3 windows (0.0%)
#   M95.4: 2 windows (0.0%)
#   N00.9: 40 windows (0.1%)
#   N02.1: 5 windows (0.0%)
#   N02.8: 16 windows (0.0%)
#   N04.0: 10 windows (0.0%)
#   N04.1: 5 windows (0.0%)
#   N04.9: 94 windows (0.2%)
#   N05.3: 5 windows (0.0%)
#   N05.9: 5 windows (0.0%)
#   N13.1: 25 windows (0.0%)
#   N13.2: 21 windows (0.0%)
#   N13.3: 249 windows (0.4%)
#   N13.5: 40 windows (0.1%)
#   N13.6: 7 windows (0.0%)
#   N13.7: 3 windows (0.0%)
#   N17.9: 3 windows (0.0%)
#   N18.0: 124 windows (0.2%)
#   N20.0: 20 windows (0.0%)
#   N20.1: 8 windows (0.0%)
#   N20.2: 3 windows (0.0%)
#   N21.1: 3 windows (0.0%)
#   N23: 2 windows (0.0%)
#   N26: 3 windows (0.0%)
#   N28.1: 5 windows (0.0%)
#   N28.8: 22 windows (0.0%)
#   N30.8: 5 windows (0.0%)
#   N31.9: 6 windows (0.0%)
#   N32.8: 9 windows (0.0%)
#   N34.2: 5 windows (0.0%)
#   N35.9: 11 windows (0.0%)
#   N36.0: 16 windows (0.0%)
#   N36.3: 5 windows (0.0%)
#   N36.8: 28 windows (0.0%)
#   N39.0: 3 windows (0.0%)
#   N43.3: 169 windows (0.3%)
#   N44: 109 windows (0.2%)
#   N45.9: 8 windows (0.0%)
#   N47: 257 windows (0.4%)
#   N48.1: 20 windows (0.0%)
#   N48.8: 68 windows (0.1%)
#   N48.9: 10 windows (0.0%)
#   N50.8: 13 windows (0.0%)
#   N50.9: 13 windows (0.0%)
#   N61: 23 windows (0.0%)
#   N62: 18 windows (0.0%)
#   N63: 13 windows (0.0%)
#   N70.1: 5 windows (0.0%)
#   N70.9: 7 windows (0.0%)
#   N73.6: 5 windows (0.0%)
#   N76.0: 3 windows (0.0%)
#   N80.9: 5 windows (0.0%)
#   N82.3: 10 windows (0.0%)
#   N83.1: 16 windows (0.0%)
#   N83.2: 24 windows (0.0%)
#   N83.5: 5 windows (0.0%)
#   N83.8: 12 windows (0.0%)
#   N83.9: 9 windows (0.0%)
#   N89.5: 15 windows (0.0%)
#   N89.7: 3 windows (0.0%)
#   N89.9: 5 windows (0.0%)
#   N90.6: 5 windows (0.0%)
#   N90.8: 10 windows (0.0%)
#   N90.9: 4 windows (0.0%)
#   N91.0: 5 windows (0.0%)
#   N94.8: 12 windows (0.0%)
#   N99.1: 5 windows (0.0%)
#   N99.8: 10 windows (0.0%)
#   O04.9: 19 windows (0.0%)
#   O26.9: 12 windows (0.0%)
#   P00.0: 5 windows (0.0%)
#   P00.2: 9 windows (0.0%)
#   P00.4: 5 windows (0.0%)
#   P00.8: 10 windows (0.0%)
#   P01.5: 10 windows (0.0%)
#   P05.1: 5 windows (0.0%)
#   P07.1: 32 windows (0.1%)
#   P07.2: 4 windows (0.0%)
#   P07.3: 41 windows (0.1%)
#   P08.1: 9 windows (0.0%)
#   P11.1: 5 windows (0.0%)
#   P20.9: 95 windows (0.2%)
#   P21.1: 8 windows (0.0%)
#   P21.9: 20 windows (0.0%)
#   P22.0: 25 windows (0.0%)
#   P22.1: 10 windows (0.0%)
#   P23.9: 40 windows (0.1%)
#   P28.5: 5 windows (0.0%)
#   P29.0: 4 windows (0.0%)
#   P29.1: 8 windows (0.0%)
#   P29.8: 19 windows (0.0%)
#   P29.9: 15 windows (0.0%)
#   P36.9: 4 windows (0.0%)
#   P39.2: 9 windows (0.0%)
#   P39.8: 5 windows (0.0%)
#   P54.3: 5 windows (0.0%)
#   P54.8: 5 windows (0.0%)
#   P55.1: 19 windows (0.0%)
#   P55.9: 5 windows (0.0%)
#   P59.9: 15 windows (0.0%)
#   P61.0: 5 windows (0.0%)
#   P74.1: 4 windows (0.0%)
#   P78.0: 5 windows (0.0%)
#   P91.9: 2 windows (0.0%)
#   P96.8: 17 windows (0.0%)
#   Q01.9: 3 windows (0.0%)
#   Q04.0: 15 windows (0.0%)
#   Q04.3: 5 windows (0.0%)
#   Q05.7: 5 windows (0.0%)
#   Q05.9: 11 windows (0.0%)
#   Q06.8: 5 windows (0.0%)
#   Q10.0: 5 windows (0.0%)
#   Q10.3: 2 windows (0.0%)
#   Q11.2: 5 windows (0.0%)
#   Q12.0: 61 windows (0.1%)
#   Q16.1: 6 windows (0.0%)
#   Q16.4: 5 windows (0.0%)
#   Q16.5: 18 windows (0.0%)
#   Q16.9: 2 windows (0.0%)
#   Q17.0: 16 windows (0.0%)
#   Q17.2: 35 windows (0.1%)
#   Q17.3: 5 windows (0.0%)
#   Q17.8: 6 windows (0.0%)
#   Q17.9: 5 windows (0.0%)
#   Q18.0: 135 windows (0.2%)
#   Q18.1: 143 windows (0.2%)
#   Q18.3: 8 windows (0.0%)
#   Q18.4: 6 windows (0.0%)
#   Q18.8: 5 windows (0.0%)
#   Q18.9: 8 windows (0.0%)
#   Q20.0: 3 windows (0.0%)
#   Q20.8: 5 windows (0.0%)
#   Q21.0: 1719 windows (2.9%)
#   Q21.1: 1651 windows (2.8%)
#   Q21.2: 42 windows (0.1%)
#   Q21.3: 114 windows (0.2%)
#   Q21.8: 38 windows (0.1%)
#   Q22.1: 3 windows (0.0%)
#   Q22.8: 10 windows (0.0%)
#   Q23.0: 8 windows (0.0%)
#   Q23.1: 10 windows (0.0%)
#   Q24.2: 10 windows (0.0%)
#   Q24.5: 30 windows (0.1%)
#   Q24.6: 15 windows (0.0%)
#   Q24.9: 64 windows (0.1%)
#   Q25.0: 446 windows (0.7%)
#   Q25.1: 5 windows (0.0%)
#   Q25.5: 5 windows (0.0%)
#   Q25.6: 8 windows (0.0%)
#   Q26.8: 15 windows (0.0%)
#   Q27.8: 41 windows (0.1%)
#   Q28.2: 5 windows (0.0%)
#   Q28.3: 23 windows (0.0%)
#   Q28.9: 5 windows (0.0%)
#   Q31.0: 3 windows (0.0%)
#   Q33.2: 5 windows (0.0%)
#   Q35.1: 5 windows (0.0%)
#   Q35.3: 5 windows (0.0%)
#   Q35.9: 228 windows (0.4%)
#   Q36.9: 38 windows (0.1%)
#   Q38.1: 42 windows (0.1%)
#   Q39.3: 10 windows (0.0%)
#   Q40.0: 5 windows (0.0%)
#   Q41.9: 3 windows (0.0%)
#   Q42.2: 5 windows (0.0%)
#   Q43.0: 19 windows (0.0%)
#   Q43.1: 12 windows (0.0%)
#   Q43.9: 5 windows (0.0%)
#   Q44.4: 3 windows (0.0%)
#   Q51.2: 7 windows (0.0%)
#   Q52.0: 3 windows (0.0%)
#   Q52.3: 11 windows (0.0%)
#   Q52.4: 12 windows (0.0%)
#   Q53.1: 20 windows (0.0%)
#   Q53.2: 10 windows (0.0%)
#   Q53.9: 130 windows (0.2%)
#   Q54.0: 5 windows (0.0%)
#   Q54.1: 5 windows (0.0%)
#   Q54.2: 5 windows (0.0%)
#   Q54.9: 71 windows (0.1%)
#   Q55.1: 5 windows (0.0%)
#   Q55.2: 16 windows (0.0%)
#   Q55.6: 300 windows (0.5%)
#   Q56.0: 5 windows (0.0%)
#   Q60.0: 5 windows (0.0%)
#   Q60.5: 5 windows (0.0%)
#   Q62.0: 3 windows (0.0%)
#   Q62.6: 5 windows (0.0%)
#   Q63.2: 5 windows (0.0%)
#   Q66.0: 14 windows (0.0%)
#   Q67.5: 10 windows (0.0%)
#   Q67.6: 202 windows (0.3%)
#   Q68.0: 21 windows (0.0%)
#   Q69.9: 36 windows (0.1%)
#   Q70.0: 3 windows (0.0%)
#   Q70.2: 5 windows (0.0%)
#   Q70.4: 26 windows (0.0%)
#   Q70.9: 23 windows (0.0%)
#   Q72.9: 5 windows (0.0%)
#   Q74.1: 6 windows (0.0%)
#   Q74.2: 2 windows (0.0%)
#   Q75.8: 5 windows (0.0%)
#   Q76.3: 19 windows (0.0%)
#   Q76.4: 12 windows (0.0%)
#   Q78.0: 10 windows (0.0%)
#   Q82.5: 3 windows (0.0%)
#   Q85.0: 5 windows (0.0%)
#   Q85.9: 5 windows (0.0%)
#   Q87.0: 8 windows (0.0%)
#   Q87.4: 5 windows (0.0%)
#   Q89.2: 104 windows (0.2%)
#   Q89.8: 7 windows (0.0%)
#   Q89.9: 5 windows (0.0%)
#   Q96.9: 4 windows (0.0%)
#   Q99.1: 5 windows (0.0%)
#   R00.0: 20 windows (0.0%)
#   R00.1: 18 windows (0.0%)
#   R00.2: 3 windows (0.0%)
#   R04.0: 9 windows (0.0%)
#   R04.2: 5 windows (0.0%)
#   R06.0: 10 windows (0.0%)
#   R06.5: 22 windows (0.0%)
#   R07.4: 5 windows (0.0%)
#   R09.8: 29 windows (0.0%)
#   R10.3: 3 windows (0.0%)
#   R10.4: 50 windows (0.1%)
#   R11: 10 windows (0.0%)
#   R15: 8 windows (0.0%)
#   R16.1: 5 windows (0.0%)
#   R19.0: 10 windows (0.0%)
#   R19.5: 10 windows (0.0%)
#   R20.8: 5 windows (0.0%)
#   R22.0: 119 windows (0.2%)
#   R22.1: 89 windows (0.1%)
#   R22.2: 48 windows (0.1%)
#   R22.3: 15 windows (0.0%)
#   R22.4: 11 windows (0.0%)
#   R22.7: 18 windows (0.0%)
#   R22.9: 25 windows (0.0%)
#   R23.4: 4 windows (0.0%)
#   R25.1: 8 windows (0.0%)
#   R25.2: 5 windows (0.0%)
#   R26.8: 5 windows (0.0%)
#   R29.0: 21 windows (0.0%)
#   R31: 11 windows (0.0%)
#   R32: 31 windows (0.1%)
#   R33: 4 windows (0.0%)
#   R40.2: 15 windows (0.0%)
#   R42: 56 windows (0.1%)
#   R43.0: 5 windows (0.0%)
#   R49.0: 5 windows (0.0%)
#   R50.8: 5 windows (0.0%)
#   R50.9: 49 windows (0.1%)
#   R51: 15 windows (0.0%)
#   R52.9: 5 windows (0.0%)
#   R53: 8 windows (0.0%)
#   R55: 75 windows (0.1%)
#   R56.0: 15 windows (0.0%)
#   R56.8: 64 windows (0.1%)
#   R57.1: 20 windows (0.0%)
#   R57.9: 3 windows (0.0%)
#   R59.0: 8 windows (0.0%)
#   R59.9: 28 windows (0.0%)
#   R62.0: 5 windows (0.0%)
#   R62.8: 51 windows (0.1%)
#   R74.8: 20 windows (0.0%)
#   R90.0: 48 windows (0.1%)
#   R93.3: 3 windows (0.0%)
#   R93.4: 10 windows (0.0%)
#   R94.5: 5 windows (0.0%)
#   S00.0: 52 windows (0.1%)
#   S00.1: 5 windows (0.0%)
#   S00.2: 3 windows (0.0%)
#   S00.3: 5 windows (0.0%)
#   S00.4: 13 windows (0.0%)
#   S00.5: 16 windows (0.0%)
#   S00.8: 30 windows (0.1%)
#   S01.0: 29 windows (0.0%)
#   S01.1: 40 windows (0.1%)
#   S01.2: 3 windows (0.0%)
#   S01.3: 5 windows (0.0%)
#   S01.4: 1 windows (0.0%)
#   S01.5: 35 windows (0.1%)
#   S01.8: 107 windows (0.2%)
#   S02.0: 22 windows (0.0%)
#   S02.1: 26 windows (0.0%)
#   S02.2: 105 windows (0.2%)
#   S02.4: 15 windows (0.0%)
#   S02.5: 5 windows (0.0%)
#   S02.6: 73 windows (0.1%)
#   S02.7: 5 windows (0.0%)
#   S02.8: 37 windows (0.1%)
#   S02.9: 47 windows (0.1%)
#   S03.0: 5 windows (0.0%)
#   S04.0: 12 windows (0.0%)
#   S05.1: 16 windows (0.0%)
#   S05.2: 3 windows (0.0%)
#   S05.3: 20 windows (0.0%)
#   S05.5: 5 windows (0.0%)
#   S05.6: 20 windows (0.0%)
#   S05.8: 10 windows (0.0%)
#   S06.2: 15 windows (0.0%)
#   S06.4: 12 windows (0.0%)
#   S06.5: 3 windows (0.0%)
#   S06.7: 20 windows (0.0%)
#   S06.8: 5 windows (0.0%)
#   S06.9: 10 windows (0.0%)
#   S09.9: 26 windows (0.0%)
#   S12.2: 5 windows (0.0%)
#   S13.1: 10 windows (0.0%)
#   S22.0: 5 windows (0.0%)
#   S22.2: 3 windows (0.0%)
#   S27.3: 21 windows (0.0%)
#   S30.1: 1 windows (0.0%)
#   S30.2: 8 windows (0.0%)
#   S31.0: 6 windows (0.0%)
#   S31.1: 5 windows (0.0%)
#   S31.4: 3 windows (0.0%)
#   S32.0: 5 windows (0.0%)
#   S32.1: 7 windows (0.0%)
#   S32.2: 3 windows (0.0%)
#   S32.4: 5 windows (0.0%)
#   S32.5: 3 windows (0.0%)
#   S32.8: 6 windows (0.0%)
#   S36.0: 5 windows (0.0%)
#   S36.1: 5 windows (0.0%)
#   S37.3: 5 windows (0.0%)
#   S39.9: 9 windows (0.0%)
#   S40.8: 7 windows (0.0%)
#   S42.0: 12 windows (0.0%)
#   S42.3: 33 windows (0.1%)
#   S42.4: 52 windows (0.1%)
#   S50.8: 2 windows (0.0%)
#   S52.1: 4 windows (0.0%)
#   S52.2: 28 windows (0.0%)
#   S52.5: 11 windows (0.0%)
#   S52.6: 8 windows (0.0%)
#   S52.7: 11 windows (0.0%)
#   S52.8: 14 windows (0.0%)
#   S60.0: 9 windows (0.0%)
#   S60.8: 3 windows (0.0%)
#   S61.0: 5 windows (0.0%)
#   S61.9: 6 windows (0.0%)
#   S62.2: 3 windows (0.0%)
#   S62.6: 3 windows (0.0%)
#   S62.8: 17 windows (0.0%)
#   S64.0: 2 windows (0.0%)
#   S66.1: 3 windows (0.0%)
#   S67.8: 6 windows (0.0%)
#   S69.9: 31 windows (0.1%)
#   S70.0: 2 windows (0.0%)
#   S71.1: 5 windows (0.0%)
#   S72.0: 3 windows (0.0%)
#   S72.2: 5 windows (0.0%)
#   S72.3: 13 windows (0.0%)
#   S72.4: 12 windows (0.0%)
#   S72.9: 32 windows (0.1%)
#   S82.0: 5 windows (0.0%)
#   S82.1: 8 windows (0.0%)
#   S82.2: 59 windows (0.1%)
#   S82.3: 19 windows (0.0%)
#   S82.5: 3 windows (0.0%)
#   S82.8: 5 windows (0.0%)
#   S83.0: 13 windows (0.0%)
#   S83.2: 5 windows (0.0%)
#   S83.5: 10 windows (0.0%)
#   S83.6: 12 windows (0.0%)
#   S85.9: 6 windows (0.0%)
#   S86.0: 2 windows (0.0%)
#   S90.3: 19 windows (0.0%)
#   S91.0: 10 windows (0.0%)
#   S92.0: 3 windows (0.0%)
#   S92.1: 8 windows (0.0%)
#   S92.3: 5 windows (0.0%)
#   S99.9: 10 windows (0.0%)
#   T00.9: 2 windows (0.0%)
#   T02.9: 13 windows (0.0%)
#   T07: 9 windows (0.0%)
#   T09.3: 5 windows (0.0%)
#   T11.9: 2 windows (0.0%)
#   T14.0: 5 windows (0.0%)
#   T14.1: 10 windows (0.0%)
#   T17.1: 5 windows (0.0%)
#   T17.4: 10 windows (0.0%)
#   T17.5: 10 windows (0.0%)
#   T18.1: 26 windows (0.0%)
#   T18.3: 5 windows (0.0%)
#   T18.9: 16 windows (0.0%)
#   T19.2: 7 windows (0.0%)
#   T20.0: 5 windows (0.0%)
#   T20.2: 9 windows (0.0%)
#   T21.2: 9 windows (0.0%)
#   T22.3: 4 windows (0.0%)
#   T23.3: 4 windows (0.0%)
#   T24.2: 5 windows (0.0%)
#   T29.0: 5 windows (0.0%)
#   T30.3: 5 windows (0.0%)
#   T35.5: 5 windows (0.0%)
#   T42.4: 5 windows (0.0%)
#   T50.9: 17 windows (0.0%)
#   T57.1: 5 windows (0.0%)
#   T58: 3 windows (0.0%)
#   T60.0: 28 windows (0.0%)
#   T60.3: 5 windows (0.0%)
#   T60.4: 8 windows (0.0%)
#   T60.9: 20 windows (0.0%)
#   T63.4: 2 windows (0.0%)
#   T78.3: 3 windows (0.0%)
#   T79.3: 5 windows (0.0%)
#   T79.6: 5 windows (0.0%)
#   T81.0: 13 windows (0.0%)
#   T81.4: 11 windows (0.0%)
#   T81.5: 5 windows (0.0%)
#   T81.8: 20 windows (0.0%)
#   T84.2: 5 windows (0.0%)
#   T85.0: 3 windows (0.0%)
#   T85.2: 15 windows (0.0%)
#   T85.3: 13 windows (0.0%)
#   T85.7: 6 windows (0.0%)
#   T86.1: 11 windows (0.0%)
#   Z00.0: 5 windows (0.0%)
#   Z00.3: 10 windows (0.0%)
#   Z08.0: 4 windows (0.0%)
#   Z09.0: 45 windows (0.1%)
#   Z29.1: 5 windows (0.0%)
#   Z41.1: 7 windows (0.0%)
#   Z42.0: 88 windows (0.1%)
#   Z42.4: 4 windows (0.0%)
#   Z43.6: 8 windows (0.0%)
#   Z45.8: 5 windows (0.0%)
#   Z46.6: 26 windows (0.0%)
#   Z47.0: 153 windows (0.3%)
#   Z47.8: 27 windows (0.0%)
#   Z48.0: 20 windows (0.0%)
#   Z48.8: 12 windows (0.0%)
#   Z48.9: 8 windows (0.0%)
#   Z51.1: 5 windows (0.0%)
#   Z51.4: 2 windows (0.0%)
#   Z51.9: 5 windows (0.0%)
#   Z52.3: 3 windows (0.0%)
#   Z54.0: 10 windows (0.0%)
#   Z90.0: 3 windows (0.0%)
#   Z96.8: 4 windows (0.0%)
#   Z98.8: 8 windows (0.0%)
#
# Number of unique diagnoses: 1493

# %% [markdown]
# ### Step 4: Perform Patient-Level Train/Validation/Test Split
# Split data at the patient level to avoid data leakage:
# - Extract unique Patient_IDs from QC summary
# - Split patient IDs (not individual windows) into 60% train, 20% val, 20% test
# - Group windows by the patient they came from
# - This ensures no patient appears in multiple sets

# %%
# Extract patient IDs from filenames in df_qc
df_qc['Patient_ID'] = df_qc['Filename'].str.split('/').str[1]

print("Unique patients in QC summary:", df_qc['Patient_ID'].nunique())
print("Total records in QC summary:", len(df_qc))

# Get patient ID for each window
# Map each window to a patient based on which record it came from
window_to_patient = []
for idx, row in df_qc.iterrows():
    n_windows = row['n_windows'] if pd.notna(row['n_windows']) else 0
    window_to_patient.extend([row['Patient_ID']] * int(n_windows))

window_to_patient = np.array(window_to_patient)
print(f"Windows mapped to patients: {len(window_to_patient)} (should match X shape[0]: {X.shape[0]})")

# Verify length matches
if len(window_to_patient) != X.shape[0]:
    print("WARNING: Mismatch between windows and patient mapping!")
    print(f"Expected {X.shape[0]} windows, got {len(window_to_patient)}")
# Out:
# Unique patients in QC summary: 11643
# Total records in QC summary: 14190
# Windows mapped to patients: 59868 (should match X shape[0]: 59868)

# %% [markdown]
# ### Step 5: Split Patient IDs and Create Train/Val/Test Sets
# Stratified split of unique patients to balance label distribution:
# - **Train**: 60% of patients (≈60% of windows)
# - **Validation**: 20% of patients (≈20% of windows)
# - **Test**: 20% of patients (≈20% of windows)

# %%
# Get unique patient IDs and their primary labels
unique_patients = df_qc['Patient_ID'].unique()
patient_labels = []

for patient_id in unique_patients:
    # Get all records for this patient and use the most common label
    patient_records = df_qc[df_qc['Patient_ID'] == patient_id]
    labels = patient_records['label_int'].dropna().values
    if len(labels) > 0:
        # Use most common label for this patient
        most_common_label = int(np.bincount(labels.astype(int)).argmax())
    else:
        most_common_label = -1
    patient_labels.append(most_common_label)

# First split: 80% train+val, 20% test
train_val_patients, test_patients, train_val_labels, test_labels = train_test_split(
    unique_patients, patient_labels,
    test_size=0.2,
    random_state=42
)

# Second split: 75% train (of train+val), 25% val (of train+val) = 60% train, 20% val overall
train_patients, val_patients, train_labels, val_labels = train_test_split(
    train_val_patients, train_val_labels,
    test_size=0.25,
    random_state=42
)

print(f"Train patients: {len(train_patients)} ({100*len(train_patients)/len(unique_patients):.1f}%)")
print(f"Val patients: {len(val_patients)} ({100*len(val_patients)/len(unique_patients):.1f}%)")
print(f"Test patients: {len(test_patients)} ({100*len(test_patients)/len(unique_patients):.1f}%)")
# Out:
# Train patients: 6985 (60.0%)
# Val patients: 2329 (20.0%)
# Test patients: 2329 (20.0%)

# %% [markdown]
# ### Step 6: Create Window Indices for Each Split
# Map patient splits back to individual windows:
# - For each split (train/val/test), collect all window indices belonging to patients in that split
# - Create corresponding X and y arrays for each split

# %%
# Create sets for faster lookup
train_patients_set = set(train_patients)
val_patients_set = set(val_patients)
test_patients_set = set(test_patients)

# Get window indices for each split
train_idx = np.where(np.isin(window_to_patient, list(train_patients_set)))[0]
val_idx = np.where(np.isin(window_to_patient, list(val_patients_set)))[0]
test_idx = np.where(np.isin(window_to_patient, list(test_patients_set)))[0]

# Create split datasets
X_train, y_train = X[train_idx], y[train_idx]
X_val, y_val = X[val_idx], y[val_idx]
X_test, y_test = X[test_idx], y[test_idx]

print("Train set:")
print(f"  X_train: {X_train.shape}")
print(f"  y_train: {y_train.shape}")

print("\nValidation set:")
print(f"  X_val: {X_val.shape}")
print(f"  y_val: {y_val.shape}")

print("\nTest set:")
print(f"  X_test: {X_test.shape}")
print(f"  y_test: {y_test.shape}")

# Verify no overlap
assert len(set(train_idx) & set(val_idx)) == 0, "Train/Val overlap detected!"
assert len(set(train_idx) & set(test_idx)) == 0, "Train/Test overlap detected!"
assert len(set(val_idx) & set(test_idx)) == 0, "Val/Test overlap detected!"
print("\n✓ No overlap between train/val/test sets")
# Out:
# Train set:
#   X_train: (35843, 5000, 1)
#   y_train: (35843,)
#
# Validation set:
#   X_val: (12034, 5000, 1)
#   y_val: (12034,)
#
# Test set:
#   X_test: (11991, 5000, 1)
#   y_test: (11991,)
#
# ✓ No overlap between train/val/test sets

# %% [markdown]
# ### Step 7: Analyze Label Distribution Across Splits
# Verify that label distribution is balanced across train/validation/test sets:
# - Show class distribution for each split
# - Confirm stratification worked correctly

# %%
def analyze_label_distribution(y, split_name, int_to_label):
    """Print label distribution for a split."""
    unique, counts = np.unique(y, return_counts=True)
    print(f"\n{split_name} label distribution:")
    for label_idx, count in zip(unique, counts):
        diagnosis = int_to_label[int(label_idx)]
        print(f"  {diagnosis}: {count} ({100*count/len(y):.1f}%)")

analyze_label_distribution(y_train, "Train", int_to_label)
analyze_label_distribution(y_val, "Validation", int_to_label)
analyze_label_distribution(y_test, "Test", int_to_label)
# Out:
# Train label distribution:
#   (F) I40.0: 208 (0.6%)
#   (FO) Q21.1: 1475 (4.1%)
#   (OSD) Q21.1: 251 (0.7%)
#   (V) I40.0: 938 (2.6%)
#   A02.9: 5 (0.0%)
#   A05.2: 5 (0.0%)
#   A08.0: 23 (0.1%)
#   A09.9: 21 (0.1%)
#   A15.3: 4 (0.0%)
#   A16.2: 20 (0.1%)
#   A16.9: 25 (0.1%)
#   A18.0: 13 (0.0%)
#   A23.9: 3 (0.0%)
#   A41.0: 5 (0.0%)
#   A41.5: 2 (0.0%)
#   A41.9: 842 (2.3%)
#   A46: 6 (0.0%)
#   A49.0: 10 (0.0%)
#   A49.1: 65 (0.2%)
#   A49.3: 174 (0.5%)
#   A49.8: 130 (0.4%)
#   A49.9: 48 (0.1%)
#   A71.9: 8 (0.0%)
#   A86: 132 (0.4%)
#   A87.9: 15 (0.0%)
#   B00.8: 10 (0.0%)
#   B00.9: 14 (0.0%)
#   B02.8: 5 (0.0%)
#   B02.9: 5 (0.0%)
#   B07: 3 (0.0%)
#   E05.0: 10 (0.1%)
#   E05.9: 10 (0.1%)
#   E06.3: 11 (0.1%)
#   E10.1: 10 (0.1%)
#   E10.9: 10 (0.1%)
#   E13.9: 14 (0.1%)
#   E14.9: 3 (0.0%)
#   E16.1: 6 (0.0%)
#   E16.2: 4 (0.0%)
#   E16.8: 15 (0.1%)
#   E20.9: 10 (0.1%)
#   E21.1: 3 (0.0%)
#   E22.1: 5 (0.0%)
#   E22.8: 5 (0.0%)
#   E23.0: 15 (0.1%)
#   E23.2: 5 (0.0%)
#   E23.6: 10 (0.1%)
#   E25.0: 9 (0.1%)
#   E28.2: 5 (0.0%)
#   E29.1: 5 (0.0%)
#   E30.0: 5 (0.0%)
#   E30.8: 8 (0.1%)
#   E32.0: 13 (0.1%)
#   E34.3: 15 (0.1%)
#   E41: 35 (0.3%)
#   E46: 46 (0.4%)
#   E53.8: 5 (0.0%)
#   E55.9: 20 (0.2%)
#   E66.9: 30 (0.2%)
#   E71.1: 9 (0.1%)
#   E72.1: 5 (0.0%)
#   E74.8: 28 (0.2%)
#   E77.8: 40 (0.3%)
#   E78.5: 5 (0.0%)
#   E83.1: 16 (0.1%)
#   E83.3: 5 (0.0%)
#   E86: 15 (0.1%)
#   E87.2: 33 (0.3%)
#   E87.5: 14 (0.1%)
#   E87.6: 29 (0.2%)
#   E87.8: 137 (1.1%)
#   E88.9: 3 (0.0%)
#   F06.8: 5 (0.0%)
#   F20.9: 20 (0.2%)
#   F31.9: 4 (0.0%)
#   F32.2: 35 (0.3%)
#   F32.3: 21 (0.2%)
#   F32.9: 10 (0.1%)
#   F42.9: 6 (0.0%)
#   F44.9: 10 (0.1%)
#   F45.0: 5 (0.0%)
#   F45.9: 5 (0.0%)
#   F51.4: 5 (0.0%)
#   F59: 10 (0.1%)
#   F79.1: 8 (0.1%)
#   F79.9: 10 (0.1%)
#   F93.9: 23 (0.2%)
#   F95.9: 11 (0.1%)
#   F98.8: 8 (0.1%)
#   F98.9: 10 (0.1%)
#   F99: 15 (0.1%)
#   G00.9: 10 (0.1%)
#   G03.0: 10 (0.1%)
#   G04.0: 3 (0.0%)
#   G04.8: 15 (0.1%)
#   G04.9: 10 (0.1%)
#   G06.0: 16 (0.1%)
#   G24.9: 10 (0.1%)
#   G25.9: 5 (0.0%)
#   G31.9: 11 (0.1%)
#   G36.0: 10 (0.1%)
#   G40.0: 5 (0.0%)
#   G40.4: 10 (0.1%)
#   G40.8: 20 (0.2%)
#   G40.9: 102 (0.8%)
#   G41.8: 3 (0.0%)
#   G41.9: 9 (0.1%)
#   G43.9: 10 (0.1%)
#   G44.1: 10 (0.1%)
#   G44.2: 5 (0.0%)
#   G47.4: 5 (0.0%)
#   G51.0: 15 (0.1%)
#   G52.2: 10 (0.1%)
#   G54.1: 3 (0.0%)
#   G56.3: 8 (0.1%)
#   G57.3: 5 (0.0%)
#   G61.0: 5 (0.0%)
#   G62.9: 5 (0.0%)
#   G70.0: 5 (0.0%)
#   G70.9: 5 (0.0%)
#   G71.0: 23 (0.2%)
#   G71.3: 5 (0.0%)
#   D22.0: 3 (0.0%)
#   D22.1: 3 (0.0%)
#   D22.3: 44 (0.4%)
#   D22.4: 10 (0.1%)
#   D22.5: 22 (0.2%)
#   D22.6: 15 (0.1%)
#   D22.7: 9 (0.1%)
#   D22.9: 15 (0.1%)
#   D23.3: 5 (0.0%)
#   D23.4: 6 (0.1%)
#   D24: 10 (0.1%)
#   D27: 28 (0.2%)
#   D31.1: 5 (0.0%)
#   D31.3: 3 (0.0%)
#   D32.0: 5 (0.0%)
#   D33.0: 10 (0.1%)
#   D33.2: 4 (0.0%)
#   D36.1: 3 (0.0%)
#   D36.7: 22 (0.2%)
#   D38.3: 20 (0.2%)
#   D39.1: 2 (0.0%)
#   D40.1: 3 (0.0%)
#   D43.2: 10 (0.1%)
#   D44.1: 10 (0.1%)
#   D44.3: 5 (0.0%)
#   D44.4: 34 (0.3%)
#   D47.7: 13 (0.1%)
#   D48.0: 2 (0.0%)
#   D48.7: 24 (0.2%)
#   D50.0: 5 (0.0%)
#   D50.9: 8 (0.1%)
#   D53.8: 5 (0.0%)
#   D56.9: 15 (0.1%)
#   D58.0: 13 (0.1%)
#   D58.9: 5 (0.0%)
#   D59.3: 3 (0.0%)
#   D61.8: 10 (0.1%)
#   D61.9: 48 (0.4%)
#   D62: 10 (0.1%)
#   D64.9: 306 (2.6%)
#   D65: 53 (0.4%)
#   D68.6: 5 (0.0%)
#   D68.9: 100 (0.8%)
#   D69.0: 208 (1.7%)
#   D69.3: 5 (0.0%)
#   D69.4: 23 (0.2%)
#   D69.6: 10 (0.1%)
#   D69.8: 4 (0.0%)
#   D70: 53 (0.4%)
#   D72.1: 11 (0.1%)
#   D75.2: 9 (0.1%)
#   D76.0: 5 (0.0%)
#   D76.1: 32 (0.3%)
#   D82.8: 10 (0.1%)
#   D86.0: 10 (0.1%)
#   E02: 5 (0.0%)
#   E03.8: 19 (0.2%)
#   E03.9: 5 (0.0%)
#   E04.1: 183 (1.5%)
#   E05.0: 5 (0.0%)
#   E05.9: 62 (0.5%)
#   E06.0: 5 (0.0%)
#   E10.1: 5 (0.0%)
#   E11.9: 5 (0.0%)
#   E13.9: 10 (0.1%)
#   E14.9: 8 (0.1%)
#   E16.1: 5 (0.0%)
#   E16.2: 5 (0.0%)
#   E20.1: 5 (0.0%)
#   E21.1: 15 (0.1%)
#   E22.1: 12 (0.1%)
#   E23.0: 27 (0.2%)
#   E23.2: 33 (0.3%)
#   E24.9: 5 (0.0%)
#   E25.0: 5 (0.0%)
#   E27.2: 5 (0.0%)
#   E27.8: 10 (0.1%)
#   E28.2: 8 (0.1%)
#   E30.0: 10 (0.1%)
#   E30.1: 5 (0.0%)
#   E34.3: 10 (0.1%)
#   E34.8: 5 (0.0%)
#   E34.9: 2 (0.0%)
#   E41: 8 (0.1%)
#   E44.0: 5 (0.0%)
#   E46: 31 (0.3%)
#   E53.8: 3 (0.0%)
#   E55.9: 16 (0.1%)
#   E66.9: 31 (0.3%)
#   E71.1: 6 (0.1%)
#   E71.3: 5 (0.0%)
#   S01.0: 5 (0.0%)
#   S01.1: 20 (0.2%)
#   S01.5: 5 (0.0%)
#   S01.8: 22 (0.2%)
#   S02.0: 10 (0.1%)
#   S02.1: 10 (0.1%)
#   S02.2: 13 (0.1%)
#   S02.6: 13 (0.1%)
#   S02.9: 14 (0.1%)
#   S04.0: 5 (0.0%)
#   S05.1: 2 (0.0%)
#   S05.8: 5 (0.0%)
#   S06.2: 5 (0.0%)
#   S06.5: 3 (0.0%)
#   S06.7: 10 (0.1%)
#   S09.9: 8 (0.1%)
#   S13.1: 5 (0.0%)
#   S27.3: 3 (0.0%)
#   S32.0: 5 (0.0%)
#   S32.2: 3 (0.0%)
#   S32.8: 3 (0.0%)
#   S37.3: 5 (0.0%)
#   S40.8: 7 (0.1%)
#   S42.0: 5 (0.0%)
#   S42.4: 19 (0.2%)
#   S52.2: 3 (0.0%)
#   S52.6: 3 (0.0%)
#   S60.8: 3 (0.0%)
#   S61.0: 5 (0.0%)
#   S61.9: 6 (0.1%)
#   S62.6: 3 (0.0%)
#   S62.8: 10 (0.1%)
#   S66.1: 3 (0.0%)
#   S71.1: 5 (0.0%)
#   S72.3: 3 (0.0%)
#   S72.4: 10 (0.1%)
#   S72.9: 10 (0.1%)
#   S82.2: 8 (0.1%)
#   S82.3: 3 (0.0%)
#   S82.5: 3 (0.0%)
#   S83.0: 5 (0.0%)
#   S83.6: 2 (0.0%)
#   S86.0: 2 (0.0%)
#   S92.1: 3 (0.0%)
#   T00.9: 2 (0.0%)
#   T07: 9 (0.1%)
#   T19.2: 2 (0.0%)
#   T20.0: 5 (0.0%)
#   T24.2: 5 (0.0%)
#   T50.9: 5 (0.0%)
#   T81.0: 3 (0.0%)
#   T81.4: 3 (0.0%)
#   T81.5: 5 (0.0%)
#   T81.8: 5 (0.0%)
#   T84.2: 5 (0.0%)
#   T85.0: 3 (0.0%)
#   T85.3: 8 (0.1%)
#   T85.7: 6 (0.1%)
#   Z00.3: 10 (0.1%)
#   Z09.0: 7 (0.1%)
#   Z41.1: 3 (0.0%)
#   Z42.0: 13 (0.1%)
#   Z46.6: 5 (0.0%)
#   Z47.0: 53 (0.4%)
#   Z48.0: 5 (0.0%)
#   Z52.3: 3 (0.0%)
#   Z54.0: 5 (0.0%)

# %% [markdown]
# ### Step 8: Define Baseline Model Architecture
# Build a 1D CNN baseline model for ECG classification:
# - **Input**: Time-series ECG windows (5000 time steps × 12 channels)
# - **Architecture**:
#   - Multiple 1D convolution layers (32, 64, 128 filters)
#   - Max pooling after each conv block
#   - Dropout for regularization
#   - Global average pooling
#   - Dense classification layers
# - **Output**: Softmax probabilities over diagnosis classes

# %%
def create_baseline_model(input_shape, num_classes):
    """
    Create a 1D CNN baseline model for ECG classification.

    Args:
        input_shape: Tuple (time_steps, channels)
        num_classes: Number of diagnosis classes

    Returns:
        Compiled Keras model
    """
    model = keras.Sequential([
        # Block 1
        layers.Input(shape=input_shape),
        layers.Conv1D(32, kernel_size=3, padding='same', activation='relu'),
        layers.Conv1D(32, kernel_size=3, padding='same', activation='relu'),
        layers.MaxPooling1D(pool_size=2),
        layers.Dropout(0.2),

        # Block 2
        layers.Conv1D(64, kernel_size=3, padding='same', activation='relu'),
        layers.Conv1D(64, kernel_size=3, padding='same', activation='relu'),
        layers.MaxPooling1D(pool_size=2),
        layers.Dropout(0.2),

        # Block 3
        layers.Conv1D(128, kernel_size=3, padding='same', activation='relu'),
        layers.Conv1D(128, kernel_size=3, padding='same', activation='relu'),
        layers.MaxPooling1D(pool_size=2),
        layers.Dropout(0.2),

        # Block 4
        layers.Conv1D(256, kernel_size=3, padding='same', activation='relu'),
        layers.Conv1D(256, kernel_size=3, padding='same', activation='relu'),
        layers.MaxPooling1D(pool_size=2),
        layers.Dropout(0.2),

        # Global average pooling and dense layers
        layers.GlobalAveragePooling1D(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])

    # Compile model
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# Create and summarize model
num_classes = len(label_to_int)
input_shape = (X_train.shape[1], X_train.shape[2])  # (time_steps, channels)

model = create_baseline_model(input_shape, num_classes)

print("Model architecture:")
model.summary()
# Out:
# Model architecture:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 5000, 32)       │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 5000, 32)       │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 2500, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 2500, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 2500, 64)       │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 2500, 64)       │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 1250, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1250, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 1250, 128)      │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 1250, 128)      │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 625, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 625, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 625, 256)       │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 625, 256)       │       196,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 312, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 312, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1493)           │       192,597 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 682,485 (2.60 MB)
#  Trainable params: 682,485 (2.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Step 9: Train Baseline Model
# Train the model with early stopping and learning rate scheduling:
# - **Batch size**: 32 windows
# - **Epochs**: Up to 100 (early stopping if no improvement)
# - **Callbacks**:
#   - Early stopping: Stop if validation loss doesn't improve for 10 epochs
#   - Learning rate reduction: Reduce LR by 50% if plateau for 5 epochs
#   - Model checkpoint: Save best model based on validation accuracy

# %%
# Create callbacks
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
model_checkpoint_path = os.path.join(RESULTS_DIR, f"baseline_model_{timestamp}.h5")

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        model_checkpoint_path,
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

# Train model
print("Training baseline model...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)

print(f"\n✓ Model saved to: {model_checkpoint_path}")
# Out:
# Training baseline model...
# Epoch 1/100
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.0365 - loss: 6.1210
# Epoch 1: val_accuracy improved from -inf to 0.04770, saving model to /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/baseline_model_20251122_151422.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 119s 82ms/step - accuracy: 0.0366 - loss: 6.1209 - val_accuracy: 0.0477 - val_loss: 6.1845 - learning_rate: 0.0010
# Epoch 2/100
# 1120/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0406 - loss: 5.8420
# Epoch 2: val_accuracy did not improve from 0.04770
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 82s 73ms/step - accuracy: 0.0406 - loss: 5.8419 - val_accuracy: 0.0477 - val_loss: 6.2642 - learning_rate: 0.0010
# Epoch 3/100
# 1120/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0414 - loss: 5.7957
# Epoch 3: val_accuracy did not improve from 0.04770
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 82s 73ms/step - accuracy: 0.0414 - loss: 5.7957 - val_accuracy: 0.0435 - val_loss: 6.2682 - learning_rate: 0.0010
# Epoch 4/100
# 1120/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.0415 - loss: 5.7005
# Epoch 4: val_accuracy did not improve from 0.04770
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 82s 73ms/step - accuracy: 0.0415 - loss: 5.7004 - val_accuracy: 0.0425 - val_loss: 6.3746 - learning_rate: 0.0010
# Epoch 5/100
# 1120/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.0417 - loss: 5.6534
# Epoch 5: val_accuracy did not improve from 0.04770
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 81s 73ms/step - accuracy: 0.0417 - loss: 5.6534 - val_accuracy: 0.0450 - val_loss: 6.4512 - learning_rate: 0.0010
# Epoch 6/100
# 1120/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0414 - loss: 5.6035
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 6: val_accuracy improved from 0.04770 to 0.05044, saving model to /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/baseline_model_20251122_151422.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 83s 74ms/step - accuracy: 0.0414 - loss: 5.6035 - val_accuracy: 0.0504 - val_loss: 6.4870 - learning_rate: 0.0010
# Epoch 7/100
# 1120/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0486 - loss: 5.5274
# Epoch 7: val_accuracy improved from 0.05044 to 0.05534, saving model to /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/baseline_model_20251122_151422.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 83s 74ms/step - accuracy: 0.0486 - loss: 5.5274 - val_accuracy: 0.0553 - val_loss: 6.5432 - learning_rate: 5.0000e-04
# Epoch 8/100
# 1120/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0504 - loss: 5.4656
# Epoch 8: val_accuracy did not improve from 0.05534
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 82s 73ms/step - accuracy: 0.0504 - loss: 5.4656 - val_accuracy: 0.0538 - val_loss: 6.6398 - learning_rate: 5.0000e-04
# Epoch 9/100
# 1120/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0543 - loss: 5.4098
# Epoch 9: val_accuracy improved from 0.05534 to 0.05809, saving model to /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/baseline_model_20251122_151422.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 83s 74ms/step - accuracy: 0.0543 - loss: 5.4097 - val_accuracy: 0.0581 - val_loss: 6.7567 - learning_rate: 5.0000e-04
# Epoch 10/100
# 1120/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0591 - loss: 5.3402
# Epoch 10: val_accuracy did not improve from 0.05809
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 82s 73ms/step - accuracy: 0.0591 - loss: 5.3402 - val_accuracy: 0.0548 - val_loss: 6.8140 - learning_rate: 5.0000e-04
# Epoch 11/100
# 1120/1121 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.0628 - loss: 5.2632
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 11: val_accuracy did not improve from 0.05809
# 1121/1121 ━━━━━━━━━━━━━━━━━━━━ 83s 74ms/step - accuracy: 0.0628 - loss: 5.2632 - val_accuracy: 0.0577 - val_loss: 6.9595 - learning_rate: 5.0000e-04
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# ✓ Model saved to: /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/baseline_model_20251122_151422.h5

# %% [markdown]
# ### Step 10: Plot Training History
# Visualize model training progress:
# - **Left**: Training and validation loss over epochs
# - **Right**: Training and validation accuracy over epochs
# - Shows whether model is learning, overfitting, or underfitting

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Loss plot
axes[0].plot(history.history['loss'], label='Train Loss', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch', fontsize=12)
axes[0].set_ylabel('Loss', fontsize=12)
axes[0].set_title('Training and Validation Loss', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].grid(True, alpha=0.3)

# Accuracy plot
axes[1].plot(history.history['accuracy'], label='Train Accuracy', linewidth=2)
axes[1].plot(history.history['val_accuracy'], label='Val Accuracy', linewidth=2)
axes[1].set_xlabel('Epoch', fontsize=12)
axes[1].set_ylabel('Accuracy', fontsize=12)
axes[1].set_title('Training and Validation Accuracy', fontsize=14, fontweight='bold')
axes[1].legend(fontsize=11)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(RESULTS_DIR, f'training_history_{timestamp}.png'), dpi=150, bbox_inches='tight')
plt.show()

print(f"✓ Training history plot saved")
# Out:
# ✓ Training history plot saved

# %% [markdown]
# ### Step 11: Evaluate on Test Set
# Comprehensive evaluation of model performance on held-out test data:
# - Overall accuracy
# - Per-class precision, recall, F1-score
# - Confusion matrix
# - ROC-AUC scores (for multi-class)

# %%
# Predictions on test set
y_test_pred_probs = model.predict(X_test, verbose=0)
y_test_pred = np.argmax(y_test_pred_probs, axis=1)

# Calculate metrics
test_accuracy = accuracy_score(y_test, y_test_pred)

print("="*70)
print("TEST SET EVALUATION")
print("="*70)
print(f"\nOverall Accuracy: {test_accuracy:.4f}\n")

# Get unique classes in test set
test_classes = np.unique(y_test)
test_class_names = [int_to_label[int(i)] for i in test_classes]

# Classification report - only on classes that appear in test set
print("Per-Class Metrics:")
print("-"*70)
report = classification_report(
    y_test, y_test_pred,
    labels=test_classes,
    target_names=test_class_names,
    digits=4
)
print(report)

# Validation accuracy for reference
y_val_pred_probs = model.predict(X_val, verbose=0)
y_val_pred = np.argmax(y_val_pred_probs, axis=1)
val_accuracy = accuracy_score(y_val, y_val_pred)

print(f"\nValidation Accuracy (final epoch): {val_accuracy:.4f}")
# Out:
# ======================================================================
# TEST SET EVALUATION
# ======================================================================
#
# Overall Accuracy: 0.0476
#
# Per-Class Metrics:
# ----------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#    (F) I40.0     0.0000    0.0000    0.0000       116
#   (FO) Q21.1     0.0476    1.0000    0.0909       571
#  (OSD) Q21.1     0.0000    0.0000    0.0000        75
#    (V) I40.0     0.0000    0.0000    0.0000       200
#        A08.0     0.0000    0.0000    0.0000         5
#        A09.0     0.0000    0.0000    0.0000        10
#        A17.8     0.0000    0.0000    0.0000        10
#        A18.3     0.0000    0.0000    0.0000         8
#        A18.8     0.0000    0.0000    0.0000         5
#        A41.9     0.0000    0.0000    0.0000       229
#        A49.1     0.0000    0.0000    0.0000        10
#        A49.3     0.0000    0.0000    0.0000        86
#        A49.8     0.0000    0.0000    0.0000        23
#        A49.9     0.0000    0.0000    0.0000        10
#        A81.1     0.0000    0.0000    0.0000         5
#          A86     0.0000    0.0000    0.0000        43
#        A87.9     0.0000    0.0000    0.0000        12
#        B00.9     0.0000    0.0000    0.0000        13
#        B01.9     0.0000    0.0000    0.0000         6
#          B09     0.0000    0.0000    0.0000         8
#        B16.9     0.0000    0.0000    0.0000        13
#        B25.9     0.0000    0.0000    0.0000        15
#        B27.9     0.0000    0.0000    0.0000         5
#        B33.2     0.0000    0.0000    0.0000         5
#        B34.0     0.0000    0.0000    0.0000        15
#        B34.1     0.0000    0.0000    0.0000        10
#        B34.8     0.0000    0.0000    0.0000        10
#        B35.0     0.0000    0.0000    0.0000        10
#          B49     0.0000    0.0000    0.0000        35
#        B82.9     0.0000    0.0000    0.0000         8
#        B83.0     0.0000    0.0000    0.0000        14
#          B99     0.0000    0.0000    0.0000        39
#        C02.9     0.0000    0.0000    0.0000         5
#        C06.9     0.0000    0.0000    0.0000         5
#        C22.9     0.0000    0.0000    0.0000         5
#        C38.3     0.0000    0.0000    0.0000         9
#        C48.2     0.0000    0.0000    0.0000        10
#        C49.9     0.0000    0.0000    0.0000         5
#        C71.1     0.0000    0.0000    0.0000         3
#        C71.2     0.0000    0.0000    0.0000        15
#        C71.5     0.0000    0.0000    0.0000         5
#        C71.6     0.0000    0.0000    0.0000        22
#        C71.7     0.0000    0.0000    0.0000         5
#        C71.9     0.0000    0.0000    0.0000        41
#          C73     0.0000    0.0000    0.0000         3
#        C75.2     0.0000    0.0000    0.0000        10
#        C76.1     0.0000    0.0000    0.0000         4
#        C76.5     0.0000    0.0000    0.0000         5
#        C79.5     0.0000    0.0000    0.0000         5
#        C81.9     0.0000    0.0000    0.0000         5
#        C83.7     0.0000    0.0000    0.0000         4
#        C85.9     0.0000    0.0000    0.0000         7
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Plot
fig, ax = plt.subplots(figsize=(12, 10))

diagnosis_names = [int_to_label[i] for i in range(num_classes)]
sns.heatmap(
    cm_normalized,
    annot=True,
    fmt='.2%',
    cmap='Blues',
    xticklabels=diagnosis_names,
    yticklabels=diagnosis_names,
    cbar_kws={'label': 'Percentage'},
    ax=ax
)

ax.set_xlabel('Predicted Label', fontsize=12, fontweight='bold')
ax.set_ylabel('True Label', fontsize=12, fontweight='bold')
ax.set_title('Normalized Confusion Matrix - Test Set', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()

plt.savefig(os.path.join(RESULTS_DIR, f'confusion_matrix_{timestamp}.png'), dpi=150, bbox_inches='tight')
plt.show()

print("✓ Confusion matrix saved")
# Out:
# ✓ Confusion matrix saved

# %% [markdown]
# ### Step 13: Save Training Results and Summary
# Export model, results, and metadata for later analysis:
# - Save trained model (HDF5 format)
# - Save training metrics (JSON)
# - Save test predictions and probabilities (NPZ)
# - Create summary report

# %%
# Save model in different formats
model_h5_path = os.path.join(RESULTS_DIR, f"baseline_model_{timestamp}.h5")
model_keras_path = os.path.join(RESULTS_DIR, f"baseline_model_{timestamp}.keras")

model.save(model_h5_path)
model.save(model_keras_path)
print(f"✓ Model saved to:")
print(f"  - {model_h5_path}")
print(f"  - {model_keras_path}")

# Save metrics and results
results = {
    'timestamp': timestamp,
    'model_type': 'Baseline 1D CNN',
    'input_shape': list(input_shape),
    'num_classes': num_classes,
    'num_parameters': int(model.count_params()),
    'training_samples': X_train.shape[0],
    'validation_samples': X_val.shape[0],
    'test_samples': X_test.shape[0],
    'epochs_trained': len(history.history['loss']),
    'final_train_loss': float(history.history['loss'][-1]),
    'final_val_loss': float(history.history['val_loss'][-1]),
    'final_train_accuracy': float(history.history['accuracy'][-1]),
    'final_val_accuracy': float(history.history['val_accuracy'][-1]),
    'test_accuracy': float(test_accuracy),
    'label_mapping': label_to_int,
}

results_json_path = os.path.join(RESULTS_DIR, f"training_results_{timestamp}.json")
with open(results_json_path, 'w') as f:
    json.dump(results, f, indent=2)
print(f"✓ Results saved to: {results_json_path}")

# Save predictions
predictions_path = os.path.join(RESULTS_DIR, f"test_predictions_{timestamp}.npz")
np.savez(
    predictions_path,
    y_true=y_test,
    y_pred=y_test_pred,
    y_probs=y_test_pred_probs
)
print(f"✓ Test predictions saved to: {predictions_path}")

# Save training history
history_path = os.path.join(RESULTS_DIR, f"training_history_{timestamp}.json")
history_dict = {
    'loss': [float(x) for x in history.history['loss']],
    'accuracy': [float(x) for x in history.history['accuracy']],
    'val_loss': [float(x) for x in history.history['val_loss']],
    'val_accuracy': [float(x) for x in history.history['val_accuracy']],
}
with open(history_path, 'w') as f:
    json.dump(history_dict, f, indent=2)
print(f"✓ Training history saved to: {history_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✓ Model saved to:
#   - /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/baseline_model_20251122_151422.h5
#   - /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/baseline_model_20251122_151422.keras
# ✓ Results saved to: /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/training_results_20251122_151422.json
# ✓ Test predictions saved to: /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/test_predictions_20251122_151422.npz
# ✓ Training history saved to: /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/training_history_20251122_151422.json

# %% [markdown]
# ### Step 14: Create Summary Report
# Generate a comprehensive summary report of the training run

# %%
summary_report = f"""
╔═══════════════════════════════════════════════════════════════════════╗
║                    BASELINE MODEL TRAINING REPORT                     ║
╚═══════════════════════════════════════════════════════════════════════╝

TRAINING CONFIGURATION
{'-'*73}
Timestamp:              {timestamp}
Model Type:             Baseline 1D CNN
Input Shape:            {input_shape}
Number of Classes:      {num_classes}
Total Parameters:       {results['num_parameters']:,}

DATA SPLITS
{'-'*73}
Train Set:              {X_train.shape[0]:,} windows from {len(train_patients)} patients
Validation Set:         {X_val.shape[0]:,} windows from {len(val_patients)} patients
Test Set:               {X_test.shape[0]:,} windows from {len(test_patients)} patients
Total:                  {X_train.shape[0] + X_val.shape[0] + X_test.shape[0]:,} windows

TRAINING RESULTS
{'-'*73}
Total Epochs Trained:   {results['epochs_trained']}
Final Train Loss:       {results['final_train_loss']:.6f}
Final Train Accuracy:   {results['final_train_accuracy']:.4f}
Final Val Loss:         {results['final_val_loss']:.6f}
Final Val Accuracy:     {results['final_val_accuracy']:.4f}

TEST SET PERFORMANCE
{'-'*73}
Test Accuracy:          {test_accuracy:.4f}

ARTIFACTS SAVED
{'-'*73}
Model (HDF5):           {model_h5_path}
Model (Keras):          {model_keras_path}
Results JSON:           {results_json_path}
Predictions (NPZ):      {predictions_path}
Training History:       {history_path}
Confusion Matrix Plot:  {os.path.join(RESULTS_DIR, f'confusion_matrix_{timestamp}.png')}
Training History Plot:  {os.path.join(RESULTS_DIR, f'training_history_{timestamp}.png')}
Summary Report:         {os.path.join(RESULTS_DIR, f'summary_report_{timestamp}.txt')}

{'-'*73}
Report generated: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}
"""

print(summary_report)

# Save report
report_path = os.path.join(RESULTS_DIR, f"summary_report_{timestamp}.txt")
with open(report_path, 'w') as f:
    f.write(summary_report)

print(f"\n✓ Summary report saved to: {report_path}")
# Out:
# ╔═══════════════════════════════════════════════════════════════════════╗
# ║                    BASELINE MODEL TRAINING REPORT                     ║
# ╚═══════════════════════════════════════════════════════════════════════╝
#
# TRAINING CONFIGURATION
# -------------------------------------------------------------------------
# Timestamp:              20251122_151422
# Model Type:             Baseline 1D CNN
# Input Shape:            (5000, 1)
# Number of Classes:      1493
# Total Parameters:       682,485
#
# DATA SPLITS
# -------------------------------------------------------------------------
# Train Set:              35,843 windows from 6985 patients
# Validation Set:         12,034 windows from 2329 patients
# Test Set:               11,991 windows from 2329 patients
# Total:                  59,868 windows
#
# TRAINING RESULTS
# -------------------------------------------------------------------------
# Total Epochs Trained:   11
# Final Train Loss:       5.246779
# Final Train Accuracy:   0.0637
# Final Val Loss:         6.959510
# Final Val Accuracy:     0.0577
#
# TEST SET PERFORMANCE
# -------------------------------------------------------------------------
# Test Accuracy:          0.0476
#
# ARTIFACTS SAVED
# -------------------------------------------------------------------------
# Model (HDF5):           /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/baseline_model_20251122_151422.h5
# Model (Keras):          /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/baseline_model_20251122_151422.keras
# Results JSON:           /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/training_results_20251122_151422.json
# Predictions (NPZ):      /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/test_predictions_20251122_151422.npz
# Training History:       /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/training_history_20251122_151422.json
# Confusion Matrix Plot:  /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/confusion_matrix_20251122_151422.png
# Training History Plot:  /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/training_history_20251122_151422.png
# Summary Report:         /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/summary_report_20251122_151422.txt
#
# -------------------------------------------------------------------------
# Report generated: 2025-11-22 15:51:10
#
#
# ✓ Summary report saved to: /content/drive/MyDrive/DeepLearningECG/artifacts/training_results/summary_report_20251122_151422.txt
